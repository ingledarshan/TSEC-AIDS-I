# %%
## Initiate Spark Session to access the clusters and Spark operations
from pyspark.sql import SparkSession
## pyspark SQL is the place where we can access all the neccassary Dataframe related functions
spark = SparkSession.builder.getOrCreate()

# %% [markdown]
# ## DataFrames - Create , Read , Load - Operations

# %%
## Create Dataframe using List of Dictionaries

from pyspark.sql.types import IntegerType, StringType, DoubleType, BooleanType
from pyspark.sql.types import StructType, StructField

#Generate toy data using a dictionary list
data = [{"Product": 'Laptop', "Brand": "HP", "Price": 99000, "Units": 2},
        {"Product": 'Smartband', "Brand": "MI", "Price": 4000, "Units": 3},
        {"Product": 'Headset', "Brand": "Boat", "Price": 3000, "Units": 2},
        {"Product": 'Mobilephone', "Brand": "Apple", "Price": 120000, "Units": 2}
        ]

# Declare the schema for the output of our function

#structfield has 3 arguments to be passed : 1. column name , 2. data type , 3. Nullable

outSchema = StructType([StructField('Product',StringType(),True),
                        StructField('Brand',StringType(),True),
                        StructField('Price',IntegerType(),True),
                        StructField('Units',IntegerType(),True),
                       ])

## Check the function createDataFrame function to conver the list of dictinoaries using 
#Create a DataFrame from the data list
df = spark.createDataFrame(data ,schema= outSchema)

## show method of dataframe class will display the created dataframe
df.show()
# Out:
# +-----------+-----+------+-----+
# |    Product|Brand| Price|Units|
# +-----------+-----+------+-----+
# |     Laptop|   HP| 99000|    2|
# |  Smartband|   MI|  4000|    3|
# |    Headset| Boat|  3000|    2|
# |Mobilephone|Apple|120000|    2|
# +-----------+-----+------+-----+

# %%
#Print the schema and view the DataFrame in table format
df.printSchema()
df.show()
# Out:
# root
#  |-- Product: string (nullable = true)
#  |-- Brand: string (nullable = true)
#  |-- Price: integer (nullable = true)
#  |-- Units: integer (nullable = true)
#
# +-----------+-----+------+-----+
# |    Product|Brand| Price|Units|
# +-----------+-----+------+-----+
# |     Laptop|   HP| 99000|    2|
# |  Smartband|   MI|  4000|    3|
# |    Headset| Boat|  3000|    2|
# |Mobilephone|Apple|120000|    2|
# +-----------+-----+------+-----+

# %%
## Create Dataframes using RDDs by defining the Schema on top of it
## Create RDD using parallelize function()
rdd = sc.parallelize([('C',85,76,87,91), ('B',85,76,87,91), ("A", 85,78,96,92), ("A", 92,76,89,96)], 4)
print("Type of the datastructure :" ,type(rdd))
## Define the schema substitute
sub = ['Division','English','Mathematics','Physics','Chemistry']
## convert rdd into dataframe using createDataFrame function by defining schema parameter
marks_df = spark.createDataFrame(rdd, schema=sub)
print("Type of the datastructure :" ,type(marks_df))
marks_df.printSchema()
marks_df.show()
# Out:
# Type of the datastructure : <class 'pyspark.rdd.RDD'>
# Type of the datastructure : <class 'pyspark.sql.dataframe.DataFrame'>
# root
#  |-- Division: string (nullable = true)
#  |-- English: long (nullable = true)
#  |-- Mathematics: long (nullable = true)
#  |-- Physics: long (nullable = true)
#  |-- Chemistry: long (nullable = true)
#
# +--------+-------+-----------+-------+---------+
# |Division|English|Mathematics|Physics|Chemistry|
# +--------+-------+-----------+-------+---------+
# |       C|     85|         76|     87|       91|
# |       B|     85|         76|     87|       91|
# |       A|     85|         78|     96|       92|
# |       A|     92|         76|     89|       96|
# +--------+-------+-----------+-------+---------+

# %%
### Reading file and converting into Dataframe
# # File location and type
# dbutils.fs.ls("/FileStore/tables/") 
# # let's consider IPL matches dataset
# file_location = "/FileStore/tables/IPL_Matches_2008_2020.csv"
# file_type = "csv"
# ##read csv files using spark.read.csv function 
# ipl_dataframe = spark.read.csv(file_location, inferSchema = True, header = True) 
# ipl_dataframe.show()

# Dataset link
# https://www.kaggle.com/datasets/patrickb1912/ipl-complete-dataset-20082020

ipl_dataframe = spark.read.format("csv").option("header", "true").load("dbfs:/FileStore/shared_uploads/darshan.ingle@thadomal.org/IPL_Matches_2008_2020.csv", inferSchema = True, header = True)
ipl_dataframe.show()
# Out:
# +------+----------+----------+---------------+--------------------+-------------+--------------------+--------------------+--------------------+-------------+--------------------+-------+-------------+----------+------+-----------+--------------+
# |    id|      city|      date|player_of_match|               venue|neutral_venue|               team1|               team2|         toss_winner|toss_decision|              winner| result|result_margin|eliminator|method|    umpire1|       umpire2|
# +------+----------+----------+---------------+--------------------+-------------+--------------------+--------------------+--------------------+-------------+--------------------+-------+-------------+----------+------+-----------+--------------+
# |335982| Bangalore|2008-04-18|    BB McCullum|M Chinnaswamy Sta...|            0|Royal Challengers...|Kolkata Knight Ri...|Royal Challengers...|        field|Kolkata Knight Ri...|   runs|          140|         N|    NA|  Asad Rauf|   RE Koertzen|
# |335983|Chandigarh|2008-04-19|     MEK Hussey|Punjab Cricket As...|            0|     Kings XI Punjab| Chennai Super Kings| Chennai Super Kings|          bat| Chennai Super Kings|   runs|           33|         N|    NA|  MR Benson|    SL Shastri|
# |335984|     Delhi|2008-04-19|    MF Maharoof|    Feroz Shah Kotla|            0|    Delhi Daredevils|    Rajasthan Royals|    Rajasthan Royals|          bat|    Delhi Daredevils|wickets|            9|         N|    NA|  Aleem Dar|GA Pratapkumar|
# |335985|    Mumbai|2008-04-20|     MV Boucher|    Wankhede Stadium|            0|      Mumbai Indians|Royal Challengers...|      Mumbai Indians|          bat|Royal Challengers...|wickets|            5|         N|    NA|   SJ Davis|     DJ Harper|
# |335986|   Kolkata|2008-04-20|      DJ Hussey|        Eden Gardens|            0|Kolkata Knight Ri...|     Deccan Chargers|     Deccan Chargers|          bat|Kolkata Knight Ri...|wickets|            5|         N|    NA|  BF Bowden|   K Hariharan|
# |335987|    Jaipur|2008-04-21|      SR Watson|Sawai Mansingh St...|            0|    Rajasthan Royals|     Kings XI Punjab|     Kings XI Punjab|          bat|    Rajasthan Royals|wickets|            6|         N|    NA|  Aleem Dar|     RB Tiffin|
# |335988| Hyderabad|2008-04-22|       V Sehwag|Rajiv Gandhi Inte...|            0|     Deccan Chargers|    Delhi Daredevils|     Deccan Chargers|          bat|    Delhi Daredevils|wickets|            9|         N|    NA|  IL Howell|     AM Saheba|
# |335989|   Chennai|2008-04-23|      ML Hayden|MA Chidambaram St...|            0| Chennai Super Kings|      Mumbai Indians|      Mumbai Indians|        field| Chennai Super Kings|   runs|            6|         N|    NA|  DJ Harper|GA Pratapkumar|
# |335990| Hyderabad|2008-04-24|      YK Pathan|Rajiv Gandhi Inte...|            0|     Deccan Chargers|    Rajasthan Royals|    Rajasthan Royals|        field|    Rajasthan Royals|wickets|            3|         N|    NA|  Asad Rauf|     MR Benson|
# |335991|Chandigarh|2008-04-25|  KC Sangakkara|Punjab Cricket As...|            0|     Kings XI Punjab|      Mumbai Indians|      Mumbai Indians|        field|     Kings XI Punjab|   runs|           66|         N|    NA|  Aleem Dar|     AM Saheba|
# |335992| Bangalore|2008-04-26|      SR Watson|M Chinnaswamy Sta...|            0|Royal Challengers...|    Rajasthan Royals|    Rajasthan Royals|        field|    Rajasthan Royals|wickets|            7|         N|    NA|  MR Benson|     IL Howell|
# |335993|   Chennai|2008-04-26|       JDP Oram|MA Chidambaram St...|            0| Chennai Super Kings|Kolkata Knight Ri...|Kolkata Knight Ri...|          bat| Chennai Super Kings|wickets|            9|         N|    NA|  BF Bowden|AV Jayaprakash|
# |335994|    Mumbai|2008-04-27|   AC Gilchrist|Dr DY Patil Sport...|            0|      Mumbai Indians|     Deccan Chargers|     Deccan Chargers|        field|     Deccan Chargers|wickets|           10|         N|    NA|  Asad Rauf|    SL Shastri|
# |335995|Chandigarh|2008-04-27|      SM Katich|Punjab Cricket As...|            0|     Kings XI Punjab|    Delhi Daredevils|    Delhi Daredevils|          bat|     Kings XI Punjab|wickets|            4|         N|    NA|RE Koertzen|     I Shivram|
# |335996| Bangalore|2008-04-28|       MS Dhoni|M Chinnaswamy Sta...|            0|Royal Challengers...| Chennai Super Kings| Chennai Super Kings|          bat| Chennai Super Kings|   runs|           13|         N|    NA|BR Doctrove|     RB Tiffin|
# |335997|   Kolkata|2008-04-29|  ST Jayasuriya|        Eden Gardens|            0|Kolkata Knight Ri...|      Mumbai Indians|Kolkata Knight Ri...|          bat|      Mumbai Indians|wickets|            7|         N|    NA|  BF Bowden|AV Jayaprakash|
# |335998|     Delhi|2008-04-30|     GD McGrath|    Feroz Shah Kotla|            0|    Delhi Daredevils|Royal Challengers...|Royal Challengers...|        field|    Delhi Daredevils|   runs|           10|         N|    NA|  Aleem Dar|     I Shivram|
# |335999| Hyderabad|2008-05-01|       SE Marsh|Rajiv Gandhi Inte...|            0|     Deccan Chargers|     Kings XI Punjab|     Kings XI Punjab|        field|     Kings XI Punjab|wickets|            7|         N|    NA|BR Doctrove|     RB Tiffin|
# |336000|    Jaipur|2008-05-01|    SA Asnodkar|Sawai Mansingh St...|            0|    Rajasthan Royals|Kolkata Knight Ri...|    Rajasthan Royals|          bat|    Rajasthan Royals|   runs|           45|         N|    NA|RE Koertzen|GA Pratapkumar|
# |336001|   Chennai|2008-05-02|       V Sehwag|MA Chidambaram St...|            0| Chennai Super Kings|    Delhi Daredevils| Chennai Super Kings|          bat|    Delhi Daredevils|wickets|            8|         N|    NA|  BF Bowden|   K Hariharan|
# +------+----------+----------+---------------+--------------------+-------------+--------------------+--------------------+--------------------+-------------+--------------------+-------+-------------+----------+------+-----------+--------------+
# only showing top 20 rows

# %%
ipl_dataframe.collect()
# Out:
# Out[43]: [Row(id=335982, city='Bangalore', date=datetime.date(2008, 4, 18), player_of_match='BB McCullum', venue='M Chinnaswamy Stadium', neutral_venue=0, team1='Royal Challengers Bangalore', team2='Kolkata Knight Riders', toss_winner='Royal Challengers Bangalore', toss_decision='field', winner='Kolkata Knight Riders', result='runs', result_margin='140', eliminator='N', method='NA', umpire1='Asad Rauf', umpire2='RE Koertzen'),
#  Row(id=335983, city='Chandigarh', date=datetime.date(2008, 4, 19), player_of_match='MEK Hussey', venue='Punjab Cricket Association Stadium, Mohali', neutral_venue=0, team1='Kings XI Punjab', team2='Chennai Super Kings', toss_winner='Chennai Super Kings', toss_decision='bat', winner='Chennai Super Kings', result='runs', result_margin='33', eliminator='N', method='NA', umpire1='MR Benson', umpire2='SL Shastri'),
#  Row(id=335984, city='Delhi', date=datetime.date(2008, 4, 19), player_of_match='MF Maharoof', venue='Feroz Shah Kotla', neutral_venue=0, team1='Delhi Daredevils', team2='Rajasthan Royals', toss_winner='Rajasthan Royals', toss_decision='bat', winner='Delhi Daredevils', result='wickets', result_margin='9', eliminator='N', method='NA', umpire1='Aleem Dar', umpire2='GA Pratapkumar'),
#  Row(id=335985, city='Mumbai', date=datetime.date(2008, 4, 20), player_of_match='MV Boucher', venue='Wankhede Stadium', neutral_venue=0, team1='Mumbai Indians', team2='Royal Challengers Bangalore', toss_winner='Mumbai Indians', toss_decision='bat', winner='Royal Challengers Bangalore', result='wickets', result_margin='5', eliminator='N', method='NA', umpire1='SJ Davis', umpire2='DJ Harper'),
#  Row(id=335986, city='Kolkata', date=datetime.date(2008, 4, 20), player_of_match='DJ Hussey', venue='Eden Gardens', neutral_venue=0, team1='Kolkata Knight Riders', team2='Deccan Chargers', toss_winner='Deccan Chargers', toss_decision='bat', winner='Kolkata Knight Riders', result='wickets', result_margin='5', eliminator='N', method='NA', umpire1='BF Bowden', umpire2='K Hariharan'),
#  Row(id=335987, city='Jaipur', date=datetime.date(2008, 4, 21), player_of_match='SR Watson', venue='Sawai Mansingh Stadium', neutral_venue=0, team1='Rajasthan Royals', team2='Kings XI Punjab', toss_winner='Kings XI Punjab', toss_decision='bat', winner='Rajasthan Royals', result='wickets', result_margin='6', eliminator='N', method='NA', umpire1='Aleem Dar', umpire2='RB Tiffin'),
#  Row(id=335988, city='Hyderabad', date=datetime.date(2008, 4, 22), player_of_match='V Sehwag', venue='Rajiv Gandhi International Stadium, Uppal', neutral_venue=0, team1='Deccan Chargers', team2='Delhi Daredevils', toss_winner='Deccan Chargers', toss_decision='bat', winner='Delhi Daredevils', result='wickets', result_margin='9', eliminator='N', method='NA', umpire1='IL Howell', umpire2='AM Saheba'),
#  Row(id=335989, city='Chennai', date=datetime.date(2008, 4, 23), player_of_match='ML Hayden', venue='MA Chidambaram Stadium, Chepauk', neutral_venue=0, team1='Chennai Super Kings', team2='Mumbai Indians', toss_winner='Mumbai Indians', toss_decision='field', winner='Chennai Super Kings', result='runs', result_margin='6', eliminator='N', method='NA', umpire1='DJ Harper', umpire2='GA Pratapkumar'),
#  Row(id=335990, city='Hyderabad', date=datetime.date(2008, 4, 24), player_of_match='YK Pathan', venue='Rajiv Gandhi International Stadium, Uppal', neutral_venue=0, team1='Deccan Chargers', team2='Rajasthan Royals', toss_winner='Rajasthan Royals', toss_decision='field', winner='Rajasthan Royals', result='wickets', result_margin='3', eliminator='N', method='NA', umpire1='Asad Rauf', umpire2='MR Benson'),
#  Row(id=335991, city='Chandigarh', date=datetime.date(2008, 4, 25), player_of_match='KC Sangakkara', venue='Punjab Cricket Association Stadium, Mohali', neutral_venue=0, team1='Kings XI Punjab', team2='Mumbai Indians', toss_winner='Mumbai Indians', toss_decision='field', winner='Kings XI Punjab', result='runs', result_margin='66', eliminator='N', method='NA', umpire1='Aleem Dar', umpire2='AM Saheba'),
#  Row(id=335992, city='Bangalore', date=datetime.date(2008, 4, 26), player_of_match='SR Watson', venue='M Chinnaswamy Stadium', neutral_venue=0, team1='Royal Challengers Bangalore', team2='Rajasthan Royals', toss_winner='Rajasthan Royals', toss_decision='field', winner='Rajasthan Royals', result='wickets', result_margin='7', eliminator='N', method='NA', umpire1='MR Benson', umpire2='IL Howell'),
#  Row(id=335993, city='Chennai', date=datetime.date(2008, 4, 26), player_of_match='JDP Oram', venue='MA Chidambaram Stadium, Chepauk', neutral_venue=0, team1='Chennai Super Kings', team2='Kolkata Knight Riders', toss_winner='Kolkata Knight Riders', toss_decision='bat', winner='Chennai Super Kings', result='wickets', result_margin='9', eliminator='N', method='NA', umpire1='BF Bowden', umpire2='AV Jayaprakash'),
#  Row(id=335994, city='Mumbai', date=datetime.date(2008, 4, 27), player_of_match='AC Gilchrist', venue='Dr DY Patil Sports Academy', neutral_venue=0, team1='Mumbai Indians', team2='Deccan Chargers', toss_winner='Deccan Chargers', toss_decision='field', winner='Deccan Chargers', result='wickets', result_margin='10', eliminator='N', method='NA', umpire1='Asad Rauf', umpire2='SL Shastri'),
#  Row(id=335995, city='Chandigarh', date=datetime.date(2008, 4, 27), player_of_match='SM Katich', venue='Punjab Cricket Association Stadium, Mohali', neutral_venue=0, team1='Kings XI Punjab', team2='Delhi Daredevils', toss_winner='Delhi Daredevils', toss_decision='bat', winner='Kings XI Punjab', result='wickets', result_margin='4', eliminator='N', method='NA', umpire1='RE Koertzen', umpire2='I Shivram'),
#  Row(id=335996, city='Bangalore', date=datetime.date(2008, 4, 28), player_of_match='MS Dhoni', venue='M Chinnaswamy Stadium', neutral_venue=0, team1='Royal Challengers Bangalore', team2='Chennai Super Kings', toss_winner='Chennai Super Kings', toss_decision='bat', winner='Chennai Super Kings', result='runs', result_margin='13', eliminator='N', method='NA', umpire1='BR Doctrove', umpire2='RB Tiffin'),
#  Row(id=335997, city='Kolkata', date=datetime.date(2008, 4, 29), player_of_match='ST Jayasuriya', venue='Eden Gardens', neutral_venue=0, team1='Kolkata Knight Riders', team2='Mumbai Indians', toss_winner='Kolkata Knight Riders', toss_decision='bat', winner='Mumbai Indians', result='wickets', result_margin='7', eliminator='N', method='NA', umpire1='BF Bowden', umpire2='AV Jayaprakash'),
#  Row(id=335998, city='Delhi', date=datetime.date(2008, 4, 30), player_of_match='GD McGrath', venue='Feroz Shah Kotla', neutral_venue=0, team1='Delhi Daredevils', team2='Royal Challengers Bangalore', toss_winner='Royal Challengers Bangalore', toss_decision='field', winner='Delhi Daredevils', result='runs', result_margin='10', eliminator='N', method='NA', umpire1='Aleem Dar', umpire2='I Shivram'),
#  Row(id=335999, city='Hyderabad', date=datetime.date(2008, 5, 1), player_of_match='SE Marsh', venue='Rajiv Gandhi International Stadium, Uppal', neutral_venue=0, team1='Deccan Chargers', team2='Kings XI Punjab', toss_winner='Kings XI Punjab', toss_decision='field', winner='Kings XI Punjab', result='wickets', result_margin='7', eliminator='N', method='NA', umpire1='BR Doctrove', umpire2='RB Tiffin'),
#  Row(id=336000, city='Jaipur', date=datetime.date(2008, 5, 1), player_of_match='SA Asnodkar', venue='Sawai Mansingh Stadium', neutral_venue=0, team1='Rajasthan Royals', team2='Kolkata Knight Riders', toss_winner='Rajasthan Royals', toss_decision='bat', winner='Rajasthan Royals', result='runs', result_margin='45', eliminator='N', method='NA', umpire1='RE Koertzen', umpire2='GA Pratapkumar'),
#  Row(id=336001, city='Chennai', date=datetime.date(2008, 5, 2), player_of_match='V Sehwag', venue='MA Chidambaram Stadium, Chepauk', neutral_venue=0, team1='Chennai Super Kings', team2='Delhi Daredevils', toss_winner='Chennai Super Kings', toss_decision='bat', winner='Delhi Daredevils', result='wickets', result_margin='8', eliminator='N', method='NA', umpire1='BF Bowden', umpire2='K Hariharan'),
#  Row(id=336002, city='Hyderabad', date=datetime.date(2008, 5, 25), player_of_match='R Vinay Kumar', venue='Rajiv Gandhi International Stadium, Uppal', neutral_venue=0, team1='Deccan Chargers', team2='Royal Challengers Bangalore', toss_winner='Deccan Chargers', toss_decision='bat', winner='Royal Challengers Bangalore', result='wickets', result_margin='5', eliminator='N', method='NA', umpire1='Asad Rauf', umpire2='RE Koertzen'),
#  Row(id=336003, city='Chandigarh', date=datetime.date(2008, 5, 3), player_of_match='IK Pathan', venue='Punjab Cricket Association Stadium, Mohali', neutral_venue=0, team1='Kings XI Punjab', team2='Kolkata Knight Riders', toss_winner='Kings XI Punjab', toss_decision='bat', winner='Kings XI Punjab', result='runs', result_margin='9', eliminator='N', method='NA', umpire1='DJ Harper', umpire2='I Shivram'),
#  Row(id=336004, city='Mumbai', date=datetime.date(2008, 5, 4), player_of_match='SM Pollock', venue='Dr DY Patil Sports Academy', neutral_venue=0, team1='Mumbai Indians', team2='Delhi Daredevils', toss_winner='Delhi Daredevils', toss_decision='field', winner='Mumbai Indians', result='runs', result_margin='29', eliminator='N', method='NA', umpire1='IL Howell', umpire2='RE Koertzen'),
#  Row(id=336005, city='Jaipur', date=datetime.date(2008, 5, 4), player_of_match='Sohail Tanvir', venue='Sawai Mansingh Stadium', neutral_venue=0, team1='Rajasthan Royals', team2='Chennai Super Kings', toss_winner='Chennai Super Kings', toss_decision='bat', winner='Rajasthan Royals', result='wickets', result_margin='8', eliminator='N', method='NA', umpire1='Asad Rauf', umpire2='AV Jayaprakash'),
#  Row(id=336006, city='Bangalore', date=datetime.date(2008, 5, 5), player_of_match='S Sreesanth', venue='M Chinnaswamy Stadium', neutral_venue=0, team1='Royal Challengers Bangalore', team2='Kings XI Punjab', toss_winner='Kings XI Punjab', toss_decision='field', winner='Kings XI Punjab', result='wickets', result_margin='6', eliminator='N', method='NA', umpire1='SJ Davis', umpire2='BR Doctrove'),
#  Row(id=336007, city='Chennai', date=datetime.date(2008, 5, 6), player_of_match='AC Gilchrist', venue='MA Chidambaram Stadium, Chepauk', neutral_venue=0, team1='Chennai Super Kings', team2='Deccan Chargers', toss_winner='Deccan Chargers', toss_decision='field', winner='Deccan Chargers', result='wickets', result_margin='7', eliminator='N', method='NA', umpire1='MR Benson', umpire2='RB Tiffin'),
#  Row(id=336008, city='Mumbai', date=datetime.date(2008, 5, 7), player_of_match='A Nehra', venue='Dr DY Patil Sports Academy', neutral_venue=0, team1='Mumbai Indians', team2='Rajasthan Royals', toss_winner='Mumbai Indians', toss_decision='field', winner='Mumbai Indians', result='wickets', result_margin='7', eliminator='N', method='NA', umpire1='DJ Harper', umpire2='RE Koertzen'),
#  Row(id=336009, city='Delhi', date=datetime.date(2008, 5, 8), player_of_match='MS Dhoni', venue='Feroz Shah Kotla', neutral_venue=0, team1='Delhi Daredevils', team2='Chennai Super Kings', toss_winner='Chennai Super Kings', toss_decision='field', winner='Chennai Super Kings', result='wickets', result_margin='4', eliminator='N', method='NA', umpire1='Aleem Dar', umpire2='RB Tiffin'),
#  Row(id=336010, city='Kolkata', date=datetime.date(2008, 5, 8), player_of_match='SC Ganguly', venue='Eden Gardens', neutral_venue=0, team1='Kolkata Knight Riders', team2='Royal Challengers Bangalore', toss_winner='Kolkata Knight Riders', toss_decision='bat', winner='Kolkata Knight Riders', result='runs', result_margin='5', eliminator='N', method='NA', umpire1='Asad Rauf', umpire2='IL Howell'),
#  Row(id=336011, city='Jaipur', date=datetime.date(2008, 5, 9), player_of_match='YK Pathan', venue='Sawai Mansingh Stadium', neutral_venue=0, team1='Rajasthan Royals', team2='Deccan Chargers', toss_winner='Rajasthan Royals', toss_decision='field', winner='Rajasthan Royals', result='wickets', result_margin='8', eliminator='N', method='NA', umpire1='MR Benson', umpire2='AM Saheba'),
#  Row(id=336012, city='Bangalore', date=datetime.date(2008, 5, 28), player_of_match='CRD Fernando', venue='M Chinnaswamy Stadium', neutral_venue=0, team1='Royal Challengers Bangalore', team2='Mumbai Indians', toss_winner='Mumbai Indians', toss_decision='field', winner='Mumbai Indians', result='wickets', result_margin='9', eliminator='N', method='NA', umpire1='BF Bowden', umpire2='AV Jayaprakash'),
#  Row(id=336013, city='Chennai', date=datetime.date(2008, 5, 10), player_of_match='L Balaji', venue='MA Chidambaram Stadium, Chepauk', neutral_venue=0, team1='Chennai Super Kings', team2='Kings XI Punjab', toss_winner='Kings XI Punjab', toss_decision='field', winner='Chennai Super Kings', result='runs', result_margin='18', eliminator='N', method='NA', umpire1='AV Jayaprakash', umpire2='BG Jerling'),
#  Row(id=336014, city='Hyderabad', date=datetime.date(2008, 5, 11), player_of_match='SC Ganguly', venue='Rajiv Gandhi International Stadium, Uppal', neutral_venue=0, team1='Deccan Chargers', team2='Kolkata Knight Riders', toss_winner='Kolkata Knight Riders', toss_decision='bat', winner='Kolkata Knight Riders', result='runs', result_margin='23', eliminator='N', method='NA', umpire1='IL Howell', umpire2='AM Saheba'),
#  Row(id=336015, city='Jaipur', date=datetime.date(2008, 5, 11), player_of_match='SR Watson', venue='Sawai Mansingh Stadium', neutral_venue=0, team1='Rajasthan Royals', team2='Delhi Daredevils', toss_winner='Rajasthan Royals', toss_decision='field', winner='Rajasthan Royals', result='wickets', result_margin='3', eliminator='N', method='NA', umpire1='SJ Davis', umpire2='RE Koertzen'),
#  Row(id=336016, city='Chandigarh', date=datetime.date(2008, 5, 12), player_of_match='SE Marsh', venue='Punjab Cricket Association Stadium, Mohali', neutral_venue=0, team1='Kings XI Punjab', team2='Royal Challengers Bangalore', toss_winner='Royal Challengers Bangalore', toss_decision='bat', winner='Kings XI Punjab', result='wickets', result_margin='9', eliminator='N', method='NA', umpire1='BR Doctrove', umpire2='I Shivram'),
#  Row(id=336017, city='Kolkata', date=datetime.date(2008, 5, 13), player_of_match='Shoaib Akhtar', venue='Eden Gardens', neutral_venue=0, team1='Kolkata Knight Riders', team2='Delhi Daredevils', toss_winner='Kolkata Knight Riders', toss_decision='bat', winner='Kolkata Knight Riders', result='runs', result_margin='23', eliminator='N', method='NA', umpire1='Asad Rauf', umpire2='IL Howell'),
#  Row(id=336018, city='Mumbai', date=datetime.date(2008, 5, 14), player_of_match='ST Jayasuriya', venue='Wankhede Stadium', neutral_venue=0, team1='Mumbai Indians', team2='Chennai Super Kings', toss_winner='Mumbai Indians', toss_decision='field', winner='Mumbai Indians', result='wickets', result_margin='9', eliminator='N', method='NA', umpire1='BR Doctrove', umpire2='AM Saheba'),
#  Row(id=336019, city='Chandigarh', date=datetime.date(2008, 5, 28), player_of_match='SE Marsh', venue='Punjab Cricket Association Stadium, Mohali', neutral_venue=0, team1='Kings XI Punjab', team2='Rajasthan Royals', toss_winner='Rajasthan Royals', toss_decision='field', winner='Kings XI Punjab', result='runs', result_margin='41', eliminator='N', method='NA', umpire1='SJ Davis', umpire2='K Hariharan'),
#  Row(id=336020, city='Delhi', date=datetime.date(2008, 5, 15), player_of_match='A Mishra', venue='Feroz Shah Kotla', neutral_venue=0, team1='Delhi Daredevils', team2='Deccan Chargers', toss_winner='Deccan Chargers', toss_decision='field', winner='Delhi Daredevils', result='runs', result_margin='12', eliminator='N', method='NA', umpire1='BG Jerling', umpire2='GA Pratapkumar'),
#  Row(id=336021, city='Mumbai', date=datetime.date(2008, 5, 16), player_of_match='SM Pollock', venue='Wankhede Stadium', neutral_venue=0, team1='Mumbai Indians', team2='Kolkata Knight Riders', toss_winner='Mumbai Indians', toss_decision='field', winner='Mumbai Indians', result='wickets', result_margin='8', eliminator='N', method='NA', umpire1='BR Doctrove', umpire2='DJ Harper'),
#  Row(id=336022, city='Delhi', date=datetime.date(2008, 5, 17), player_of_match='DPMD Jayawardene', venue='Feroz Shah Kotla', neutral_venue=0, team1='Delhi Daredevils', team2='Kings XI Punjab', toss_winner='Delhi Daredevils', toss_decision='bat', winner='Kings XI Punjab', result='runs', result_margin='6', eliminator='N', method='D/L', umpire1='AV Jayaprakash', umpire2='RE Koertzen'),
#  Row(id=336023, city='Jaipur', date=datetime.date(2008, 5, 17), player_of_match='GC Smith', venue='Sawai Mansingh Stadium', neutral_venue=0, team1='Rajasthan Royals', team2='Royal Challengers Bangalore', toss_winner='Royal Challengers Bangalore', toss_decision='field', winner='Rajasthan Royals', result='runs', result_margin='65', eliminator='N', method='NA', umpire1='BF Bowden', umpire2='SL Shastri'),
#  Row(id=336024, city='Hyderabad', date=datetime.date(2008, 5, 18), player_of_match='DJ Bravo', venue='Rajiv Gandhi International Stadium, Uppal', neutral_venue=0, team1='Deccan Chargers', team2='Mumbai Indians', toss_winner='Deccan Chargers', toss_decision='field', winner='Mumbai Indians', result='runs', result_margin='25', eliminator='N', method='NA', umpire1='BR Doctrove', umpire2='DJ Harper'),
#  Row(id=336025, city='Kolkata', date=datetime.date(2008, 5, 18), player_of_match='M Ntini', venue='Eden Gardens', neutral_venue=0, team1='Kolkata Knight Riders', team2='Chennai Super Kings', toss_winner='Kolkata Knight Riders', toss_decision='bat', winner='Chennai Super Kings', result='runs', result_margin='3', eliminator='N', method='D/L', umpire1='Asad Rauf', umpire2='K Hariharan'),
#  Row(id=336026, city='Bangalore', date=datetime.date(2008, 5, 19), player_of_match='SP Goswami', venue='M Chinnaswamy Stadium', neutral_venue=0, team1='Royal Challengers Bangalore', team2='Delhi Daredevils', toss_winner='Delhi Daredevils', toss_decision='field', winner='Delhi Daredevils', result='wickets', result_margin='5', eliminator='N', method='NA', umpire1='SJ Davis', umpire2='GA Pratapkumar'),
#  Row(id=336027, city='Kolkata', date=datetime.date(2008, 5, 20), player_of_match='YK Pathan', venue='Eden Gardens', neutral_venue=0, team1='Kolkata Knight Riders', team2='Rajasthan Royals', toss_winner='Rajasthan Royals', toss_decision='field', winner='Rajasthan Royals', result='wickets', result_margin='6', eliminator='N', method='NA', umpire1='BG Jerling', umpire2='RE Koertzen'),
#  Row(id=336028, city='Mumbai', date=datetime.date(2008, 5, 21), player_of_match='SE Marsh', venue='Wankhede Stadium', neutral_venue=0, team1='Mumbai Indians', team2='Kings XI Punjab', toss_winner='Mumbai Indians', toss_decision='field', winner='Kings XI Punjab', result='runs', result_margin='1', eliminator='N', method='NA', umpire1='BF Bowden', umpire2='GA Pratapkumar'),
#  Row(id=336029, city='Chennai', date=datetime.date(2008, 5, 21), player_of_match='A Kumble', venue='MA Chidambaram Stadium, Chepauk', neutral_venue=0, team1='Chennai Super Kings', team2='Royal Challengers Bangalore', toss_winner='Royal Challengers Bangalore', toss_decision='bat', winner='Royal Challengers Bangalore', result='runs', result_margin='14', eliminator='N', method='NA', umpire1='DJ Harper', umpire2='I Shivram'),
#  Row(id=336031, city='Chandigarh', date=datetime.date(2008, 5, 23), player_of_match='SE Marsh', venue='Punjab Cricket Association Stadium, Mohali', neutral_venue=0, team1='Kings XI Punjab', team2='Deccan Chargers', toss_winner='Kings XI Punjab', toss_decision='field', winner='Kings XI Punjab', result='wickets', result_margin='6', eliminator='N', method='NA', umpire1='Asad Rauf', umpire2='SJ Davis'),
#  Row(id=336032, city='Delhi', date=datetime.date(2008, 5, 24), player_of_match='KD Karthik', venue='Feroz Shah Kotla', neutral_venue=0, team1='Delhi Daredevils', team2='Mumbai Indians', toss_winner='Delhi Daredevils', toss_decision='field', winner='Delhi Daredevils', result='wickets', result_margin='5', eliminator='N', method='NA', umpire1='BF Bowden', umpire2='K Hariharan'),
#  Row(id=336033, city='Chennai', date=datetime.date(2008, 5, 24), player_of_match='JA Morkel', venue='MA Chidambaram Stadium, Chepauk', neutral_venue=0, team1='Chennai Super Kings', team2='Rajasthan Royals', toss_winner='Rajasthan Royals', toss_decision='bat', winner='Rajasthan Royals', result='runs', result_margin='10', eliminator='N', method='NA', umpire1='DJ Harper', umpire2='SL Shastri'),
#  Row(id=336034, city='Bangalore', date=datetime.date(2008, 5, 3), player_of_match='P Kumar', venue='M Chinnaswamy Stadium', neutral_venue=0, team1='Royal Challengers Bangalore', team2='Deccan Chargers', toss_winner='Deccan Chargers', toss_decision='field', winner='Royal Challengers Bangalore', result='runs', result_margin='3', eliminator='N', method='NA', umpire1='BR Doctrove', umpire2='SL Shastri'),
#  Row(id=336035, city='Kolkata', date=datetime.date(2008, 5, 25), player_of_match='Umar Gul', venue='Eden Gardens', neutral_venue=0, team1='Kolkata Knight Riders', team2='Kings XI Punjab', toss_winner='Kings XI Punjab', toss_decision='bat', winner='Kolkata Knight Riders', result='wickets', result_margin='3', eliminator='N', method='NA', umpire1='SJ Davis', umpire2='I Shivram'),
#  Row(id=336036, city='Jaipur', date=datetime.date(2008, 5, 26), player_of_match='Sohail Tanvir', venue='Sawai Mansingh Stadium', neutral_venue=0, team1='Rajasthan Royals', team2='Mumbai Indians', toss_winner='Rajasthan Royals', toss_decision='field', winner='Rajasthan Royals', result='wickets', result_margin='5', eliminator='N', method='NA', umpire1='BF Bowden', umpire2='K Hariharan'),
#  Row(id=336037, city='Hyderabad', date=datetime.date(2008, 5, 27), player_of_match='SK Raina', venue='Rajiv Gandhi International Stadium, Uppal', neutral_venue=0, team1='Deccan Chargers', team2='Chennai Super Kings', toss_winner='Deccan Chargers', toss_decision='bat', winner='Chennai Super Kings', result='wickets', result_margin='7', eliminator='N', method='NA', umpire1='BG Jerling', umpire2='AM Saheba'),
#  Row(id=336038, city='Mumbai', date=datetime.date(2008, 5, 30), player_of_match='SR Watson', venue='Wankhede Stadium', neutral_venue=0, team1='Delhi Daredevils', team2='Rajasthan Royals', toss_winner='Delhi Daredevils', toss_decision='field', winner='Rajasthan Royals', result='runs', result_margin='105', eliminator='N', method='NA', umpire1='BF Bowden', umpire2='RE Koertzen'),
#  Row(id=336039, city='Mumbai', date=datetime.date(2008, 5, 31), player_of_match='M Ntini', venue='Wankhede Stadium', neutral_venue=0, team1='Chennai Super Kings', team2='Kings XI Punjab', toss_winner='Kings XI Punjab', toss_decision='bat', winner='Chennai Super Kings', result='wickets', result_margin='9', eliminator='N', method='NA', umpire1='Asad Rauf', umpire2='DJ Harper'),
#  Row(id=336040, city='Mumbai', date=datetime.date(2008, 6, 1), player_of_match='YK Pathan', venue='Dr DY Patil Sports Academy', neutral_venue=0, team1='Chennai Super Kings', team2='Rajasthan Royals', toss_winner='Rajasthan Royals', toss_decision='field', winner='Rajasthan Royals', result='wickets', result_margin='3', eliminator='N', method='NA', umpire1='BF Bowden', umpire2='RE Koertzen'),
#  Row(id=392181, city='Cape Town', date=datetime.date(2009, 4, 18), player_of_match='SR Tendulkar', venue='Newlands', neutral_venue=1, team1='Chennai Super Kings', team2='Mumbai Indians', toss_winner='Chennai Super Kings', toss_decision='field', winner='Mumbai Indians', result='runs', result_margin='19', eliminator='N', method='NA', umpire1='BR Doctrove', umpire2='K Hariharan'),
#  Row(id=392182, city='Cape Town', date=datetime.date(2009, 4, 18), player_of_match='R Dravid', venue='Newlands', neutral_venue=1, team1='Royal Challengers Bangalore', team2='Rajasthan Royals', toss_winner='Royal Challengers Bangalore', toss_decision='bat', winner='Royal Challengers Bangalore', result='runs', result_margin='75', eliminator='N', method='NA', umpire1='BR Doctrove', umpire2='RB Tiffin'),
#  Row(id=392183, city='Cape Town', date=datetime.date(2009, 4, 19), player_of_match='DL Vettori', venue='Newlands', neutral_venue=1, team1='Delhi Daredevils', team2='Kings XI Punjab', toss_winner='Delhi Daredevils', toss_decision='field', winner='Delhi Daredevils', result='wickets', result_margin='10', eliminator='N', method='D/L', umpire1='MR Benson', umpire2='SD Ranade'),
#  Row(id=392184, city='Cape Town', date=datetime.date(2009, 4, 19), player_of_match='RP Singh', venue='Newlands', neutral_venue=1, team1='Deccan Chargers', team2='Kolkata Knight Riders', toss_winner='Kolkata Knight Riders', toss_decision='bat', winner='Deccan Chargers', result='wickets', result_margin='8', eliminator='N', method='NA', umpire1='MR Benson', umpire2='BR Doctrove'),
#  Row(id=392185, city='Port Elizabeth', date=datetime.date(2009, 4, 20), player_of_match='M Muralitharan', venue="St George's Park", neutral_venue=1, team1='Royal Challengers Bangalore', team2='Chennai Super Kings', toss_winner='Chennai Super Kings', toss_decision='bat', winner='Chennai Super Kings', result='runs', result_margin='92', eliminator='N', method='NA', umpire1='BG Jerling', umpire2='SJA Taufel'),
#  Row(id=392186, city='Durban', date=datetime
#
# *** WARNING: max output size exceeded, skipping output. ***
#
# ', date=datetime.date(2019, 5, 10), player_of_match='F du Plessis', venue='Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium', neutral_venue=0, team1='Chennai Super Kings', team2='Delhi Capitals', toss_winner='Chennai Super Kings', toss_decision='field', winner='Chennai Super Kings', result='wickets', result_margin='6', eliminator='N', method='NA', umpire1='BNJ Oxenford', umpire2='S Ravi'),
#  Row(id=1181768, city='Hyderabad', date=datetime.date(2019, 5, 12), player_of_match='JJ Bumrah', venue='Rajiv Gandhi International Stadium, Uppal', neutral_venue=0, team1='Mumbai Indians', team2='Chennai Super Kings', toss_winner='Mumbai Indians', toss_decision='bat', winner='Mumbai Indians', result='runs', result_margin='1', eliminator='N', method='NA', umpire1='IJ Gould', umpire2='Nitin Menon'),
#  Row(id=1216492, city='Abu Dhabi', date=datetime.date(2020, 9, 19), player_of_match='AT Rayudu', venue='Sheikh Zayed Stadium', neutral_venue=0, team1='Mumbai Indians', team2='Chennai Super Kings', toss_winner='Chennai Super Kings', toss_decision='field', winner='Chennai Super Kings', result='wickets', result_margin='5', eliminator='N', method='NA', umpire1='CB Gaffaney', umpire2='VK Sharma'),
#  Row(id=1216493, city='Dubai', date=datetime.date(2020, 9, 20), player_of_match='MP Stoinis', venue='Dubai International Cricket Stadium', neutral_venue=0, team1='Delhi Capitals', team2='Kings XI Punjab', toss_winner='Kings XI Punjab', toss_decision='field', winner='Delhi Capitals', result='tie', result_margin='NA', eliminator='Y', method='NA', umpire1='AK Chaudhary', umpire2='Nitin Menon'),
#  Row(id=1216494, city='Abu Dhabi', date=datetime.date(2020, 10, 21), player_of_match='Mohammed Siraj', venue='Sheikh Zayed Stadium', neutral_venue=0, team1='Kolkata Knight Riders', team2='Royal Challengers Bangalore', toss_winner='Kolkata Knight Riders', toss_decision='bat', winner='Royal Challengers Bangalore', result='wickets', result_margin='8', eliminator='N', method='NA', umpire1='VK Sharma', umpire2='S Ravi'),
#  Row(id=1216495, city='Sharjah', date=datetime.date(2020, 11, 3), player_of_match='S Nadeem', venue='Sharjah Cricket Stadium', neutral_venue=0, team1='Mumbai Indians', team2='Sunrisers Hyderabad', toss_winner='Sunrisers Hyderabad', toss_decision='field', winner='Sunrisers Hyderabad', result='wickets', result_margin='10', eliminator='N', method='NA', umpire1='C Shamshuddin', umpire2='RK Illingworth'),
#  Row(id=1216496, city='Sharjah', date=datetime.date(2020, 9, 22), player_of_match='SV Samson', venue='Sharjah Cricket Stadium', neutral_venue=0, team1='Rajasthan Royals', team2='Chennai Super Kings', toss_winner='Chennai Super Kings', toss_decision='field', winner='Rajasthan Royals', result='runs', result_margin='16', eliminator='N', method='NA', umpire1='C Shamshuddin', umpire2='VA Kulkarni'),
#  Row(id=1216497, city='Abu Dhabi', date=datetime.date(2020, 10, 24), player_of_match='CV Varun', venue='Sheikh Zayed Stadium', neutral_venue=0, team1='Kolkata Knight Riders', team2='Delhi Capitals', toss_winner='Delhi Capitals', toss_decision='field', winner='Kolkata Knight Riders', result='runs', result_margin='59', eliminator='N', method='NA', umpire1='CB Gaffaney', umpire2='PG Pathak'),
#  Row(id=1216498, city='Dubai', date=datetime.date(2020, 10, 24), player_of_match='CJ Jordan', venue='Dubai International Cricket Stadium', neutral_venue=0, team1='Kings XI Punjab', team2='Sunrisers Hyderabad', toss_winner='Sunrisers Hyderabad', toss_decision='field', winner='Kings XI Punjab', result='runs', result_margin='12', eliminator='N', method='NA', umpire1='AY Dandekar', umpire2='PR Reiffel'),
#  Row(id=1216499, city='Abu Dhabi', date=datetime.date(2020, 10, 28), player_of_match='SA Yadav', venue='Sheikh Zayed Stadium', neutral_venue=0, team1='Royal Challengers Bangalore', team2='Mumbai Indians', toss_winner='Mumbai Indians', toss_decision='field', winner='Mumbai Indians', result='wickets', result_margin='5', eliminator='N', method='NA', umpire1='UV Gandhe', umpire2='CB Gaffaney'),
#  Row(id=1216500, city='Sharjah', date=datetime.date(2020, 10, 9), player_of_match='R Ashwin', venue='Sharjah Cricket Stadium', neutral_venue=0, team1='Delhi Capitals', team2='Rajasthan Royals', toss_winner='Rajasthan Royals', toss_decision='field', winner='Delhi Capitals', result='runs', result_margin='46', eliminator='N', method='NA', umpire1='KN Ananthapadmanabhan', umpire2='C Shamshuddin'),
#  Row(id=1216501, city='Abu Dhabi', date=datetime.date(2020, 10, 7), player_of_match='RA Tripathi', venue='Sheikh Zayed Stadium', neutral_venue=0, team1='Kolkata Knight Riders', team2='Chennai Super Kings', toss_winner='Kolkata Knight Riders', toss_decision='bat', winner='Kolkata Knight Riders', result='runs', result_margin='10', eliminator='N', method='NA', umpire1='KN Ananthapadmanabhan', umpire2='RK Illingworth'),
#  Row(id=1216502, city='Sharjah', date=datetime.date(2020, 10, 31), player_of_match='Sandeep Sharma', venue='Sharjah Cricket Stadium', neutral_venue=0, team1='Royal Challengers Bangalore', team2='Sunrisers Hyderabad', toss_winner='Sunrisers Hyderabad', toss_decision='field', winner='Sunrisers Hyderabad', result='wickets', result_margin='5', eliminator='N', method='NA', umpire1='KN Ananthapadmanabhan', umpire2='K Srinivasan'),
#  Row(id=1216503, city='Abu Dhabi', date=datetime.date(2020, 10, 1), player_of_match='KA Pollard', venue='Sheikh Zayed Stadium', neutral_venue=0, team1='Mumbai Indians', team2='Kings XI Punjab', toss_winner='Kings XI Punjab', toss_decision='field', winner='Mumbai Indians', result='runs', result_margin='48', eliminator='N', method='NA', umpire1='VK Sharma', umpire2='S Ravi'),
#  Row(id=1216504, city='Dubai', date=datetime.date(2020, 9, 30), player_of_match='Shivam Mavi', venue='Dubai International Cricket Stadium', neutral_venue=0, team1='Kolkata Knight Riders', team2='Rajasthan Royals', toss_winner='Rajasthan Royals', toss_decision='field', winner='Kolkata Knight Riders', result='runs', result_margin='37', eliminator='N', method='NA', umpire1='KN Ananthapadmanabhan', umpire2='C Shamshuddin'),
#  Row(id=1216505, city='Abu Dhabi', date=datetime.date(2020, 11, 2), player_of_match='A Nortje', venue='Sheikh Zayed Stadium', neutral_venue=0, team1='Royal Challengers Bangalore', team2='Delhi Capitals', toss_winner='Delhi Capitals', toss_decision='field', winner='Delhi Capitals', result='wickets', result_margin='6', eliminator='N', method='NA', umpire1='CB Gaffaney', umpire2='S Ravi'),
#  Row(id=1216506, city='Abu Dhabi', date=datetime.date(2020, 11, 1), player_of_match='RD Gaikwad', venue='Sheikh Zayed Stadium', neutral_venue=0, team1='Kings XI Punjab', team2='Chennai Super Kings', toss_winner='Chennai Super Kings', toss_decision='field', winner='Chennai Super Kings', result='wickets', result_margin='9', eliminator='N', method='NA', umpire1='PG Pathak', umpire2='VK Sharma'),
#  Row(id=1216507, city='Dubai', date=datetime.date(2020, 10, 11), player_of_match='R Tewatia', venue='Dubai International Cricket Stadium', neutral_venue=0, team1='Sunrisers Hyderabad', team2='Rajasthan Royals', toss_winner='Sunrisers Hyderabad', toss_decision='bat', winner='Rajasthan Royals', result='wickets', result_margin='5', eliminator='N', method='NA', umpire1='YC Barde', umpire2='PR Reiffel'),
#  Row(id=1216508, city='Abu Dhabi', date=datetime.date(2020, 9, 23), player_of_match='RG Sharma', venue='Sheikh Zayed Stadium', neutral_venue=0, team1='Mumbai Indians', team2='Kolkata Knight Riders', toss_winner='Kolkata Knight Riders', toss_decision='field', winner='Mumbai Indians', result='runs', result_margin='49', eliminator='N', method='NA', umpire1='CB Gaffaney', umpire2='S Ravi'),
#  Row(id=1216509, city='Sharjah', date=datetime.date(2020, 10, 17), player_of_match='S Dhawan', venue='Sharjah Cricket Stadium', neutral_venue=0, team1='Chennai Super Kings', team2='Delhi Capitals', toss_winner='Chennai Super Kings', toss_decision='bat', winner='Delhi Capitals', result='wickets', result_margin='5', eliminator='N', method='NA', umpire1='KN Ananthapadmanabhan', umpire2='RK Illingworth'),
#  Row(id=1216510, city='Dubai', date=datetime.date(2020, 9, 24), player_of_match='KL Rahul', venue='Dubai International Cricket Stadium', neutral_venue=0, team1='Kings XI Punjab', team2='Royal Challengers Bangalore', toss_winner='Royal Challengers Bangalore', toss_decision='field', winner='Kings XI Punjab', result='runs', result_margin='97', eliminator='N', method='NA', umpire1='AK Chaudhary', umpire2='PR Reiffel'),
#  Row(id=1216511, city='Abu Dhabi', date=datetime.date(2020, 10, 6), player_of_match='SA Yadav', venue='Sheikh Zayed Stadium', neutral_venue=0, team1='Mumbai Indians', team2='Rajasthan Royals', toss_winner='Mumbai Indians', toss_decision='bat', winner='Mumbai Indians', result='runs', result_margin='57', eliminator='N', method='NA', umpire1='VK Sharma', umpire2='S Ravi'),
#  Row(id=1216512, city='Abu Dhabi', date=datetime.date(2020, 10, 18), player_of_match='LH Ferguson', venue='Sheikh Zayed Stadium', neutral_venue=0, team1='Kolkata Knight Riders', team2='Sunrisers Hyderabad', toss_winner='Sunrisers Hyderabad', toss_decision='field', winner='Kolkata Knight Riders', result='tie', result_margin='NA', eliminator='Y', method='NA', umpire1='PG Pathak', umpire2='S Ravi'),
#  Row(id=1216513, city='Dubai', date=datetime.date(2020, 10, 4), player_of_match='SR Watson', venue='Dubai International Cricket Stadium', neutral_venue=0, team1='Kings XI Punjab', team2='Chennai Super Kings', toss_winner='Kings XI Punjab', toss_decision='bat', winner='Chennai Super Kings', result='wickets', result_margin='10', eliminator='N', method='NA', umpire1='AY Dandekar', umpire2='Nitin Menon'),
#  Row(id=1216514, city='Abu Dhabi', date=datetime.date(2020, 10, 3), player_of_match='YS Chahal', venue='Sheikh Zayed Stadium', neutral_venue=0, team1='Rajasthan Royals', team2='Royal Challengers Bangalore', toss_winner='Rajasthan Royals', toss_decision='bat', winner='Royal Challengers Bangalore', result='wickets', result_margin='8', eliminator='N', method='NA', umpire1='CB Gaffaney', umpire2='S Ravi'),
#  Row(id=1216515, city='Sharjah', date=datetime.date(2020, 10, 3), player_of_match='SS Iyer', venue='Sharjah Cricket Stadium', neutral_venue=0, team1='Delhi Capitals', team2='Kolkata Knight Riders', toss_winner='Kolkata Knight Riders', toss_decision='field', winner='Delhi Capitals', result='runs', result_margin='18', eliminator='N', method='NA', umpire1='VA Kulkarni', umpire2='RK Illingworth'),
#  Row(id=1216516, city='Dubai', date=datetime.date(2020, 10, 2), player_of_match='PK Garg', venue='Dubai International Cricket Stadium', neutral_venue=0, team1='Sunrisers Hyderabad', team2='Chennai Super Kings', toss_winner='Sunrisers Hyderabad', toss_decision='bat', winner='Sunrisers Hyderabad', result='runs', result_margin='7', eliminator='N', method='NA', umpire1='AK Chaudhary', umpire2='PR Reiffel'),
#  Row(id=1216517, city='Dubai', date=datetime.date(2020, 10, 18), player_of_match='KL Rahul', venue='Dubai International Cricket Stadium', neutral_venue=0, team1='Mumbai Indians', team2='Kings XI Punjab', toss_winner='Mumbai Indians', toss_decision='bat', winner='Kings XI Punjab', result='tie', result_margin='NA', eliminator='Y', method='NA', umpire1='Nitin Menon', umpire2='PR Reiffel'),
#  Row(id=1216518, city='Dubai', date=datetime.date(2020, 10, 22), player_of_match='MK Pandey', venue='Dubai International Cricket Stadium', neutral_venue=0, team1='Rajasthan Royals', team2='Sunrisers Hyderabad', toss_winner='Sunrisers Hyderabad', toss_decision='field', winner='Sunrisers Hyderabad', result='wickets', result_margin='8', eliminator='N', method='NA', umpire1='Nitin Menon', umpire2='PR Reiffel'),
#  Row(id=1216519, city='Dubai', date=datetime.date(2020, 10, 5), player_of_match='AR Patel', venue='Dubai International Cricket Stadium', neutral_venue=0, team1='Delhi Capitals', team2='Royal Challengers Bangalore', toss_winner='Royal Challengers Bangalore', toss_decision='field', winner='Delhi Capitals', result='runs', result_margin='59', eliminator='N', method='NA', umpire1='Nitin Menon', umpire2='YC Barde'),
#  Row(id=1216520, city='Sharjah', date=datetime.date(2020, 10, 26), player_of_match='CH Gayle', venue='Sharjah Cricket Stadium', neutral_venue=0, team1='Kolkata Knight Riders', team2='Kings XI Punjab', toss_winner='Kings XI Punjab', toss_decision='field', winner='Kings XI Punjab', result='wickets', result_margin='8', eliminator='N', method='NA', umpire1='KN Ananthapadmanabhan', umpire2='RK Illingworth'),
#  Row(id=1216521, city='Sharjah', date=datetime.date(2020, 10, 23), player_of_match='TA Boult', venue='Sharjah Cricket Stadium', neutral_venue=0, team1='Chennai Super Kings', team2='Mumbai Indians', toss_winner='Mumbai Indians', toss_decision='field', winner='Mumbai Indians', result='wickets', result_margin='10', eliminator='N', method='NA', umpire1='C Shamshuddin', umpire2='VA Kulkarni'),
#  Row(id=1216522, city='Dubai', date=datetime.date(2020, 10, 17), player_of_match='AB de Villiers', venue='Dubai International Cricket Stadium', neutral_venue=0, team1='Rajasthan Royals', team2='Royal Challengers Bangalore', toss_winner='Rajasthan Royals', toss_decision='bat', winner='Royal Challengers Bangalore', result='wickets', result_margin='7', eliminator='N', method='NA', umpire1='AK Chaudhary', umpire2='Nitin Menon'),
#  Row(id=1216523, city='Abu Dhabi', date=datetime.date(2020, 10, 10), player_of_match='KD Karthik', venue='Sheikh Zayed Stadium', neutral_venue=0, team1='Kolkata Knight Riders', team2='Kings XI Punjab', toss_winner='Kolkata Knight Riders', toss_decision='bat', winner='Kolkata Knight Riders', result='runs', result_margin='2', eliminator='N', method='NA', umpire1='UV Gandhe', umpire2='CB Gaffaney'),
#  Row(id=1216524, city='Dubai', date=datetime.date(2020, 10, 27), player_of_match='WP Saha', venue='Dubai International Cricket Stadium', neutral_venue=0, team1='Sunrisers Hyderabad', team2='Delhi Capitals', toss_winner='Delhi Capitals', toss_decision='field', winner='Sunrisers Hyderabad', result='runs', result_margin='88', eliminator='N', method='NA', umpire1='AK Chaudhary', umpire2='Nitin Menon'),
#  Row(id=1216525, city='Dubai', date=datetime.date(2020, 10, 10), player_of_match='V Kohli', venue='Dubai International Cricket Stadium', neutral_venue=0, team1='Royal Challengers Bangalore', team2='Chennai Super Kings', toss_winner='Royal Challengers Bangalore', toss_decision='bat', winner='Royal Challengers Bangalore', result='runs', result_margin='37', eliminator='N', method='NA', umpire1='AK Chaudhary', umpire2='PR Reiffel'),
#  Row(id=1216526, city='Abu Dhabi', date=datetime.date(2020, 10, 16), player_of_match='Q de Kock', venue='Sheikh Zayed Stadium', neutral_venue=0, team1='Kolkata Knight Riders', team2='Mumbai Indians', toss_winner='Kolkata Knight Riders', toss_decision='bat', winner='Mumbai Indians', result='wickets', result_margin='8', eliminator='N', method='NA', umpire1='CB Gaffaney', umpire2='VK Sharma'),
#  Row(id=1216527, city='Sharjah', date=datetime.date(2020, 9, 27), player_of_match='SV Samson', venue='Sharjah Cricket Stadium', neutral_venue=0, team1='Kings XI Punjab', team2='Rajasthan Royals', toss_winner='Rajasthan Royals', toss_decision='field', winner='Rajasthan Royals', result='wickets', result_margin='4', eliminator='N', method='NA', umpire1='RK Illingworth', umpire2='K Srinivasan'),
#  Row(id=1216528, city='Dubai', date=datetime.date(2020, 10, 13), player_of_match='RA Jadeja', venue='Dubai International Cricket Stadium', neutral_venue=0, team1='Chennai Super Kings', team2='Sunrisers Hyderabad', toss_winner='Chennai Super Kings', toss_decision='bat', winner='Chennai Super Kings', result='runs', result_margin='20', eliminator='N', method='NA', umpire1='AK Chaudhary', umpire2='PR Reiffel'),
#  Row(id=1216529, city='Abu Dhabi', date=datetime.date(2020, 10, 11), player_of_match='Q de Kock', venue='Sheikh Zayed Stadium', neutral_venue=0, team1='Delhi Capitals', team2='Mumbai Indians', toss_winner='Delhi Capitals', toss_decision='bat', winner='Mumbai Indians', result='wickets', result_margin='5', eliminator='N', method='NA', umpire1='CB Gaffaney', umpire2='S Ravi'),
#  Row(id=1216530, city='Dubai', date=datetime.date(2020, 11, 1), player_of_match='PJ Cummins', venue='Dubai International Cricket Stadium', neutral_venue=0, team1='Kolkata Knight Riders', team2='Rajasthan Royals', toss_winner='Rajasthan Royals', toss_decision='field', winner='Kolkata Knight Riders', result='runs', result_margin='60', eliminator='N', method='NA', umpire1='Nitin Menon', umpire2='PR Reiffel'),
#  Row(id=1216531, city='Sharjah', date=datetime.date(2020, 10, 15), player_of_match='KL Rahul', venue='Sharjah Cricket Stadium', neutral_venue=0, team1='Royal Challengers Bangalore', team2='Kings XI Punjab', toss_winner='Royal Challengers Bangalore', toss_decision='bat', winner='Kings XI Punjab', result='wickets', result_margin='8', eliminator='N', method='NA', umpire1='KN Ananthapadmanabhan', umpire2='C Shamshuddin'),
#  Row(id=1216532, city='Abu Dhabi', date=datetime.date(2020, 9, 29), player_of_match='Rashid Khan', venue='Sheikh Zayed Stadium', neutral_venue=0, team1='Sunrisers Hyderabad', team2='Delhi Capitals', toss_winner='Delhi Capitals', toss_decision='field', winner='Sunrisers Hyderabad', result='runs', result_margin='15', eliminator='N', method='NA', umpire1='VK Sharma', umpire2='S Ravi'),
#  Row(id=1216533, city='Abu Dhabi', date=datetime.date(2020, 10, 19), player_of_match='JC Buttler', venue='Sheikh Zayed Stadium', neutral_venue=0, team1='Chennai Super Kings', team2='Rajasthan Royals', toss_winner='Chennai Super Kings', toss_decision='bat', winner='Rajasthan Royals', result='wickets', result_margin='7', eliminator='N', method='NA', umpire1='CB Gaffaney', umpire2='VK Sharma'),
#  Row(id=1216534, city='Dubai', date=datetime.date(2020, 9, 21), player_of_match='YS Chahal', venue='Dubai International Cricket Stadium', neutral_venue=0, team1='Royal Challengers Bangalore', team2='Sunrisers Hyderabad', toss_winner='Sunrisers Hyderabad', toss_decision='field', winner='Royal Challengers Bangalore', result='runs', result_margin='10', eliminator='N', method='NA', umpire1='AY Dandekar', umpire2='Nitin Menon'),
#  Row(id=1216535, city='Dubai', date=datetime.date(2020, 10, 31), player_of_match='Ishan Kishan', venue='Dubai International Cricket Stadium', neutral_venue=0, team1='Delhi Capitals', team2='Mumbai Indians', toss_winner='Mumbai Indians', toss_decision='field', winner='Mumbai Indians', result='wickets', result_margin='9', eliminator='N', method='NA', umpire1='YC Barde', umpire2='PR Reiffel'),
#  Row(id=1216536, city='Dubai', date=datetime.date(2020, 10, 29), player_of_match='RD Gaikwad', venue='Dubai International Cricket Stadium', neutral_venue=0, team1='Kolkata Knight Riders', team2='Chennai Super Kings', toss_winner='Chennai Super Kings', toss_decision='field', winner='Chennai Super Kings', result='wickets', result_margin='6', eliminator='N', method='NA', umpire1='C Shamshuddin', umpire2='RK Illingworth'),
#  Row(id=1216537, city='Abu Dhabi', date=datetime.date(2020, 10, 30), player_of_match='BA Stokes', venue='Sheikh Zayed Stadium', neutral_venue=0, team1='Kings XI Punjab', team2='Rajasthan Royals', toss_winner='Rajasthan Royals', toss_decision='field', winner='Rajasthan Royals', result='wickets', result_margin='7', eliminator='N', method='NA', umpire1='CB Gaffaney', umpire2='S Ravi'),
#  Row(id=1216538, city='Sharjah', date=datetime.date(2020, 10, 4), player_of_match='TA Boult', venue='Sharjah Cricket Stadium', neutral_venue=0, team1='Mumbai Indians', team2='Sunrisers Hyderabad', toss_winner='Mumbai Indians', toss_decision='bat', winner='Mumbai Indians', result='runs', result_margin='34', eliminator='N', method='NA', umpire1='KN Ananthapadmanabhan', umpire2='RK Illingworth'),
#  Row(id=1216539, city='Dubai', date=datetime.date(2020, 9, 25), player_of_match='PP Shaw', venue='Dubai International Cricket Stadium', neutral_venue=0, team1='Delhi Capitals', team2='Chennai Super Kings', toss_winner='Chennai Super Kings', toss_decision='field', winner='Delhi Capitals', result='runs', result_margin='44', eliminator='N', method='NA', umpire1='KN Ananthapadmanabhan', umpire2='RK Illingworth'),
#  Row(id=1216540, city='Sharjah', date=datetime.date(2020, 10, 12), player_of_match='AB de Villiers', venue='Sharjah Cricket Stadium', neutral_venue=0, team1='Royal Challengers Bangalore', team2='Kolkata Knight Riders', toss_winner='Royal Challengers Bangalore', toss_decision='bat', winner='Royal Challengers Bangalore', result='runs', result_margin='82', eliminator='N', method='NA', umpire1='RK Illingworth', umpire2='K Srinivasan'),
#  Row(id=1216541, city='Abu Dhabi', date=datetime.date(2020, 10, 25), player_of_match='BA Stokes', venue='Sheikh Zayed Stadium', neutral_venue=0, team1='Mumbai Indians', team2='Rajasthan Royals', toss_winner='Mumbai Indians', toss_decision='bat', winner='Rajasthan Royals', result='wickets', result_margin='8', eliminator='N', method='NA', umpire1='UV Gandhe', umpire2='VK Sharma'),
#  Row(id=1216542, city='Dubai', date=datetime.date(2020, 10, 8), player_of_match='JM Bairstow', venue='Dubai International Cricket Stadium', neutral_venue=0, team1='Sunrisers Hyderabad', team2='Kings XI Punjab', toss_winner='Sunrisers Hyderabad', toss_decision='bat', winner='Sunrisers Hyderabad', result='runs', result_margin='69', eliminator='N', method='NA', umpire1='AK Chaudhary', umpire2='Nitin Menon'),
#  Row(id=1216543, city='Dubai', date=datetime.date(2020, 10, 14), player_of_match='A Nortje', venue='Dubai International Cricket Stadium', neutral_venue=0, team1='Delhi Capitals', team2='Rajasthan Royals', toss_winner='Delhi Capitals', toss_decision='bat', winner='Delhi Capitals', result='runs', result_margin='13', eliminator='N', method='NA', umpire1='AK Chaudhary', umpire2='Nitin Menon'),
#  Row(id=1216544, city='Dubai', date=datetime.date(2020, 10, 25), player_of_match='RD Gaikwad', venue='Dubai International Cricket Stadium', neutral_venue=0, team1='Royal Challengers Bangalore', team2='Chennai Super Kings', toss_winner='Royal Challengers Bangalore', toss_decision='bat', winner='Chennai Super Kings', result='wickets', result_margin='8', eliminator='N', method='NA', umpire1='C Shamshuddin', umpire2='RK Illingworth'),
#  Row(id=1216545, city='Abu Dhabi', date=datetime.date(2020, 9, 26), player_of_match='Shubman Gill', venue='Sheikh Zayed Stadium', neutral_venue=0, team1='Sunrisers Hyderabad', team2='Kolkata Knight Riders', toss_winner='Sunrisers Hyderabad', toss_decision='bat', winner='Kolkata Knight Riders', result='wickets', result_margin='7', eliminator='N', method='NA', umpire1='CB Gaffaney', umpire2='VK Sharma'),
#  Row(id=1216546, city='Dubai', date=datetime.date(2020, 10, 20), player_of_match='S Dhawan', venue='Dubai International Cricket Stadium', neutral_venue=0, team1='Delhi Capitals', team2='Kings XI Punjab', toss_winner='Delhi Capitals', toss_decision='bat', winner='Kings XI Punjab', result='wickets', result_margin='5', eliminator='N', method='NA', umpire1='C Shamshuddin', umpire2='RK Illingworth'),
#  Row(id=1216547, city='Dubai', date=datetime.date(2020, 9, 28), player_of_match='AB de Villiers', venue='Dubai International Cricket Stadium', neutral_venue=0, team1='Royal Challengers Bangalore', team2='Mumbai Indians', toss_winner='Mumbai Indians', toss_decision='field', winner='Royal Challengers Bangalore', result='tie', result_margin='NA', eliminator='Y', method='NA', umpire1='Nitin Menon', umpire2='PR Reiffel'),
#  Row(id=1237177, city='Dubai', date=datetime.date(2020, 11, 5), player_of_match='JJ Bumrah', venue='Dubai International Cricket Stadium', neutral_venue=0, team1='Mumbai Indians', team2='Delhi Capitals', toss_winner='Delhi Capitals', toss_decision='field', winner='Mumbai Indians', result='runs', result_margin='57', eliminator='N', method='NA', umpire1='CB Gaffaney', umpire2='Nitin Menon'),
#  Row(id=1237178, city='Abu Dhabi', date=datetime.date(2020, 11, 6), player_of_match='KS Williamson', venue='Sheikh Zayed Stadium', neutral_venue=0, team1='Royal Challengers Bangalore', team2='Sunrisers Hyderabad', toss_winner='Sunrisers Hyderabad', toss_decision='field', winner='Sunrisers Hyderabad', result='wickets', result_margin='6', eliminator='N', method='NA', umpire1='PR Reiffel', umpire2='S Ravi'),
#  Row(id=1237180, city='Abu Dhabi', date=datetime.date(2020, 11, 8), player_of_match='MP Stoinis', venue='Sheikh Zayed Stadium', neutral_venue=0, team1='Delhi Capitals', team2='Sunrisers Hyderabad', toss_winner='Delhi Capitals', toss_decision='bat', winner='Delhi Capitals', result='runs', result_margin='17', eliminator='N', method='NA', umpire1='PR Reiffel', umpire2='S Ravi'),
#  Row(id=1237181, city='Dubai', date=datetime.date(2020, 11, 10), player_of_match='TA Boult', venue='Dubai International Cricket Stadium', neutral_venue=0, team1='Delhi Capitals', team2='Mumbai Indians', toss_winner='Delhi Capitals', toss_decision='bat', winner='Mumbai Indians', result='wickets', result_margin='5', eliminator='N', method='NA', umpire1='CB Gaffaney', umpire2='Nitin Menon')]

# %%
## view first 2 rows of ipl_dataframe
ipl_dataframe.take(2)
# Out:
# Out[44]: [Row(id=335982, city='Bangalore', date=datetime.date(2008, 4, 18), player_of_match='BB McCullum', venue='M Chinnaswamy Stadium', neutral_venue=0, team1='Royal Challengers Bangalore', team2='Kolkata Knight Riders', toss_winner='Royal Challengers Bangalore', toss_decision='field', winner='Kolkata Knight Riders', result='runs', result_margin='140', eliminator='N', method='NA', umpire1='Asad Rauf', umpire2='RE Koertzen'),
#  Row(id=335983, city='Chandigarh', date=datetime.date(2008, 4, 19), player_of_match='MEK Hussey', venue='Punjab Cricket Association Stadium, Mohali', neutral_venue=0, team1='Kings XI Punjab', team2='Chennai Super Kings', toss_winner='Chennai Super Kings', toss_decision='bat', winner='Chennai Super Kings', result='runs', result_margin='33', eliminator='N', method='NA', umpire1='MR Benson', umpire2='SL Shastri')]

# %%
## view last 2 rows of ipl_dataframe
ipl_dataframe.tail(2)
# Out:
# Out[45]: [Row(id=1237180, city='Abu Dhabi', date=datetime.date(2020, 11, 8), player_of_match='MP Stoinis', venue='Sheikh Zayed Stadium', neutral_venue=0, team1='Delhi Capitals', team2='Sunrisers Hyderabad', toss_winner='Delhi Capitals', toss_decision='bat', winner='Delhi Capitals', result='runs', result_margin='17', eliminator='N', method='NA', umpire1='PR Reiffel', umpire2='S Ravi'),
#  Row(id=1237181, city='Dubai', date=datetime.date(2020, 11, 10), player_of_match='TA Boult', venue='Dubai International Cricket Stadium', neutral_venue=0, team1='Delhi Capitals', team2='Mumbai Indians', toss_winner='Delhi Capitals', toss_decision='bat', winner='Mumbai Indians', result='wickets', result_margin='5', eliminator='N', method='NA', umpire1='CB Gaffaney', umpire2='Nitin Menon')]

# %%
ipl_dataframe.head(2)
# Out:
# Out[46]: [Row(id=335982, city='Bangalore', date=datetime.date(2008, 4, 18), player_of_match='BB McCullum', venue='M Chinnaswamy Stadium', neutral_venue=0, team1='Royal Challengers Bangalore', team2='Kolkata Knight Riders', toss_winner='Royal Challengers Bangalore', toss_decision='field', winner='Kolkata Knight Riders', result='runs', result_margin='140', eliminator='N', method='NA', umpire1='Asad Rauf', umpire2='RE Koertzen'),
#  Row(id=335983, city='Chandigarh', date=datetime.date(2008, 4, 19), player_of_match='MEK Hussey', venue='Punjab Cricket Association Stadium, Mohali', neutral_venue=0, team1='Kings XI Punjab', team2='Chennai Super Kings', toss_winner='Chennai Super Kings', toss_decision='bat', winner='Chennai Super Kings', result='runs', result_margin='33', eliminator='N', method='NA', umpire1='MR Benson', umpire2='SL Shastri')]

# %%
# #different file reading ways

# dataframe_json = spark.read.json('data\json_data.json') 
# dataframe_txt = spark.read.text('data\text_data.txt') 
# dataframe_csv = spark.read.csv('data\csv_data.csv') 
# dataframe_parquet = spark.read.load('data\parquet_data.parquet')

# %%
ipl_dataframe.columns
# Out:
# Out[48]: ['id',
#  'city',
#  'date',
#  'player_of_match',
#  'venue',
#  'neutral_venue',
#  'team1',
#  'team2',
#  'toss_winner',
#  'toss_decision',
#  'winner',
#  'result',
#  'result_margin',
#  'eliminator',
#  'method',
#  'umpire1',
#  'umpire2']

# %%
print("List of Columns :" , ipl_dataframe.columns)
print("Row Count :",ipl_dataframe.count()) 
print("Column Count :",len(ipl_dataframe.columns))
# Out:
# List of Columns : ['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result', 'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2']
# Row Count : 816
# Column Count : 17

# %%
## select few columns only / subset the dataframe using select function 

subset_ipl_data = ipl_dataframe.select("id","city","date","player_of_match","venue")

subset_ipl_data.show()
# Out:
# +------+----------+----------+---------------+--------------------+
# |    id|      city|      date|player_of_match|               venue|
# +------+----------+----------+---------------+--------------------+
# |335982| Bangalore|2008-04-18|    BB McCullum|M Chinnaswamy Sta...|
# |335983|Chandigarh|2008-04-19|     MEK Hussey|Punjab Cricket As...|
# |335984|     Delhi|2008-04-19|    MF Maharoof|    Feroz Shah Kotla|
# |335985|    Mumbai|2008-04-20|     MV Boucher|    Wankhede Stadium|
# |335986|   Kolkata|2008-04-20|      DJ Hussey|        Eden Gardens|
# |335987|    Jaipur|2008-04-21|      SR Watson|Sawai Mansingh St...|
# |335988| Hyderabad|2008-04-22|       V Sehwag|Rajiv Gandhi Inte...|
# |335989|   Chennai|2008-04-23|      ML Hayden|MA Chidambaram St...|
# |335990| Hyderabad|2008-04-24|      YK Pathan|Rajiv Gandhi Inte...|
# |335991|Chandigarh|2008-04-25|  KC Sangakkara|Punjab Cricket As...|
# |335992| Bangalore|2008-04-26|      SR Watson|M Chinnaswamy Sta...|
# |335993|   Chennai|2008-04-26|       JDP Oram|MA Chidambaram St...|
# |335994|    Mumbai|2008-04-27|   AC Gilchrist|Dr DY Patil Sport...|
# |335995|Chandigarh|2008-04-27|      SM Katich|Punjab Cricket As...|
# |335996| Bangalore|2008-04-28|       MS Dhoni|M Chinnaswamy Sta...|
# |335997|   Kolkata|2008-04-29|  ST Jayasuriya|        Eden Gardens|
# |335998|     Delhi|2008-04-30|     GD McGrath|    Feroz Shah Kotla|
# |335999| Hyderabad|2008-05-01|       SE Marsh|Rajiv Gandhi Inte...|
# |336000|    Jaipur|2008-05-01|    SA Asnodkar|Sawai Mansingh St...|
# |336001|   Chennai|2008-05-02|       V Sehwag|MA Chidambaram St...|
# +------+----------+----------+---------------+--------------------+
# only showing top 20 rows

# %%
ipl_dataframe.printSchema()
# Out:
# root
#  |-- id: integer (nullable = true)
#  |-- city: string (nullable = true)
#  |-- date: date (nullable = true)
#  |-- player_of_match: string (nullable = true)
#  |-- venue: string (nullable = true)
#  |-- neutral_venue: integer (nullable = true)
#  |-- team1: string (nullable = true)
#  |-- team2: string (nullable = true)
#  |-- toss_winner: string (nullable = true)
#  |-- toss_decision: string (nullable = true)
#  |-- winner: string (nullable = true)
#  |-- result: string (nullable = true)
#  |-- result_margin: string (nullable = true)
#  |-- eliminator: string (nullable = true)
#  |-- method: string (nullable = true)
#  |-- umpire1: string (nullable = true)
#  |-- umpire2: string (nullable = true)

# %%
## select and creating new columns / modifying them using column expressions
from pyspark.sql.functions import weekofyear

#here we use weekofyear function from sql.functions 
## we are creating a new column "Weekofyear" by extracting the week of year from date column 
## alias is used to rename the column

subset_ipl_data = ipl_dataframe.select("id","city","date","player_of_match","venue",(weekofyear(ipl_dataframe.date) + 10).alias('WeekOfYear'))

subset_ipl_data.show()
# Out:
# +------+----------+----------+---------------+--------------------+----------+
# |    id|      city|      date|player_of_match|               venue|WeekOfYear|
# +------+----------+----------+---------------+--------------------+----------+
# |335982| Bangalore|2008-04-18|    BB McCullum|M Chinnaswamy Sta...|        26|
# |335983|Chandigarh|2008-04-19|     MEK Hussey|Punjab Cricket As...|        26|
# |335984|     Delhi|2008-04-19|    MF Maharoof|    Feroz Shah Kotla|        26|
# |335985|    Mumbai|2008-04-20|     MV Boucher|    Wankhede Stadium|        26|
# |335986|   Kolkata|2008-04-20|      DJ Hussey|        Eden Gardens|        26|
# |335987|    Jaipur|2008-04-21|      SR Watson|Sawai Mansingh St...|        27|
# |335988| Hyderabad|2008-04-22|       V Sehwag|Rajiv Gandhi Inte...|        27|
# |335989|   Chennai|2008-04-23|      ML Hayden|MA Chidambaram St...|        27|
# |335990| Hyderabad|2008-04-24|      YK Pathan|Rajiv Gandhi Inte...|        27|
# |335991|Chandigarh|2008-04-25|  KC Sangakkara|Punjab Cricket As...|        27|
# |335992| Bangalore|2008-04-26|      SR Watson|M Chinnaswamy Sta...|        27|
# |335993|   Chennai|2008-04-26|       JDP Oram|MA Chidambaram St...|        27|
# |335994|    Mumbai|2008-04-27|   AC Gilchrist|Dr DY Patil Sport...|        27|
# |335995|Chandigarh|2008-04-27|      SM Katich|Punjab Cricket As...|        27|
# |335996| Bangalore|2008-04-28|       MS Dhoni|M Chinnaswamy Sta...|        28|
# |335997|   Kolkata|2008-04-29|  ST Jayasuriya|        Eden Gardens|        28|
# |335998|     Delhi|2008-04-30|     GD McGrath|    Feroz Shah Kotla|        28|
# |335999| Hyderabad|2008-05-01|       SE Marsh|Rajiv Gandhi Inte...|        28|
# |336000|    Jaipur|2008-05-01|    SA Asnodkar|Sawai Mansingh St...|        28|
# |336001|   Chennai|2008-05-02|       V Sehwag|MA Chidambaram St...|        28|
# +------+----------+----------+---------------+--------------------+----------+
# only showing top 20 rows

# %%
## selecting columns based on regex - colRegex function

regex_subset = ipl_dataframe.select(ipl_dataframe.colRegex("`player.+$`"))
regex_subset.show(5)
# Out:
# +---------------+
# |player_of_match|
# +---------------+
# |    BB McCullum|
# |     MEK Hussey|
# |    MF Maharoof|
# |     MV Boucher|
# |      DJ Hussey|
# +---------------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import lit

## Create New column using withColumn method
## lit function is being used to create a constant value across all the rows 
ipl_dataframe.select(ipl_dataframe.columns[2:4]).withColumn("Country", lit("India")).show(5)
# Out:
# +----------+---------------+-------+
# |      date|player_of_match|Country|
# +----------+---------------+-------+
# |2008-04-18|    BB McCullum|  India|
# |2008-04-19|     MEK Hussey|  India|
# |2008-04-19|    MF Maharoof|  India|
# |2008-04-20|     MV Boucher|  India|
# |2008-04-20|      DJ Hussey|  India|
# +----------+---------------+-------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import lit , weekofyear , dayofyear

## Create multiple columns , conversions using chaining operations withColumn function

## the popular way of writing multiple chain operations

ipl_dataframe.select(ipl_dataframe.columns[1:5]).withColumn("WeekOfYear", weekofyear(ipl_dataframe.date)).withColumn("DayofYear",dayofyear(ipl_dataframe.date)).withColumn("Country",lit("india")).show(5)
# Out:
# +----------+----------+---------------+--------------------+----------+---------+-------+
# |      city|      date|player_of_match|               venue|WeekOfYear|DayofYear|Country|
# +----------+----------+---------------+--------------------+----------+---------+-------+
# | Bangalore|2008-04-18|    BB McCullum|M Chinnaswamy Sta...|        16|      109|  india|
# |Chandigarh|2008-04-19|     MEK Hussey|Punjab Cricket As...|        16|      110|  india|
# |     Delhi|2008-04-19|    MF Maharoof|    Feroz Shah Kotla|        16|      110|  india|
# |    Mumbai|2008-04-20|     MV Boucher|    Wankhede Stadium|        16|      111|  india|
# |   Kolkata|2008-04-20|      DJ Hussey|        Eden Gardens|        16|      111|  india|
# +----------+----------+---------------+--------------------+----------+---------+-------+
# only showing top 5 rows

# %%
## creating a custom user defined function to get the shortform of the given colum ( winner column )
def customudf(column):
  values = column.split(" ")
  if len(values) <=2:
    short_form = values[0][0]+values[1][0]
  elif len(values)>2:
    short_form = values[0][0]+values[1][0]+values[2][0]
  return short_form
      
## we use udf function to convert our custom udf into pyspark udf       
from pyspark.sql.functions import udf,col
from pyspark.sql.types import StringType

## conversion of udf to pyspark udf
udf_spark= udf(lambda x:customudf(x),StringType())

## applying our function on top of winner column
ipl_dataframe.withColumn("Winner_ShortForm",udf_spark(col("winner"))).select("id","winner","Winner_ShortForm").show(5)
# Out:
# +------+--------------------+----------------+
# |    id|              winner|Winner_ShortForm|
# +------+--------------------+----------------+
# |335982|Kolkata Knight Ri...|             KKR|
# |335983| Chennai Super Kings|             CSK|
# |335984|    Delhi Daredevils|              DD|
# |335985|Royal Challengers...|             RCB|
# |335986|Kolkata Knight Ri...|             KKR|
# +------+--------------------+----------------+
# only showing top 5 rows

# %%
## distinct function 

ipl_dataframe.withColumn("Winner_ShortForm",udf_spark(col("winner"))).select("winner","Winner_ShortForm").distinct().show(9)
# Out:
# +--------------------+----------------+
# |              winner|Winner_ShortForm|
# +--------------------+----------------+
# |Kolkata Knight Ri...|             KKR|
# |Royal Challengers...|             RCB|
# |      Mumbai Indians|              MI|
# |Kochi Tuskers Kerala|             KTK|
# |    Rajasthan Royals|              RR|
# |     Deccan Chargers|              DC|
# | Chennai Super Kings|             CSK|
# |     Kings XI Punjab|             KXP|
# |    Delhi Daredevils|              DD|
# +--------------------+----------------+
# only showing top 9 rows

# %%
### Droping columns 

#lets create a copy of the ipl_dataframe

ipl_dataframe_copy = ipl_dataframe

ipl_dataframe_copy.select(ipl_dataframe_copy.columns[1:5]).drop("winner").show(5)
# Out:
# +----------+----------+---------------+--------------------+
# |      city|      date|player_of_match|               venue|
# +----------+----------+---------------+--------------------+
# | Bangalore|2008-04-18|    BB McCullum|M Chinnaswamy Sta...|
# |Chandigarh|2008-04-19|     MEK Hussey|Punjab Cricket As...|
# |     Delhi|2008-04-19|    MF Maharoof|    Feroz Shah Kotla|
# |    Mumbai|2008-04-20|     MV Boucher|    Wankhede Stadium|
# |   Kolkata|2008-04-20|      DJ Hussey|        Eden Gardens|
# +----------+----------+---------------+--------------------+
# only showing top 5 rows

# %%
## Describe function 

ipl_dataframe.select("player_of_match").describe().show()
# Out:
# +-------+---------------+
# |summary|player_of_match|
# +-------+---------------+
# |  count|            816|
# |   mean|           null|
# | stddev|           null|
# |    min|     A Chandila|
# |    max|         Z Khan|
# +-------+---------------+

# %%
## converting into Pandas dataframe - to_pandas_on_spark() 

# ipl_dataframe.to_pandas_on_spark()

# %%
## Rename column names using withColumnRenamed 

ipl_dataframe = ipl_dataframe.withColumnRenamed("winner","Winning_team_name")

ipl_dataframe.columns
# Out:
# Out[61]: ['id',
#  'city',
#  'date',
#  'player_of_match',
#  'venue',
#  'neutral_venue',
#  'team1',
#  'team2',
#  'toss_winner',
#  'toss_decision',
#  'Winning_team_name',
#  'result',
#  'result_margin',
#  'eliminator',
#  'method',
#  'umpire1',
#  'umpire2']

# %%
ipl_dataframe
# Out:
# Out[62]: DataFrame[id: int, city: string, date: date, player_of_match: string, venue: string, neutral_venue: int, team1: string, team2: string, toss_winner: string, toss_decision: string, Winning_team_name: string, result: string, result_margin: string, eliminator: string, method: string, umpire1: string, umpire2: string]

# %%
ipl_dataframe.printSchema()
# Out:
# root
#  |-- id: integer (nullable = true)
#  |-- city: string (nullable = true)
#  |-- date: date (nullable = true)
#  |-- player_of_match: string (nullable = true)
#  |-- venue: string (nullable = true)
#  |-- neutral_venue: integer (nullable = true)
#  |-- team1: string (nullable = true)
#  |-- team2: string (nullable = true)
#  |-- toss_winner: string (nullable = true)
#  |-- toss_decision: string (nullable = true)
#  |-- Winning_team_name: string (nullable = true)
#  |-- result: string (nullable = true)
#  |-- result_margin: string (nullable = true)
#  |-- eliminator: string (nullable = true)
#  |-- method: string (nullable = true)
#  |-- umpire1: string (nullable = true)
#  |-- umpire2: string (nullable = true)

# %%
# ipl_dataframe.select("result_margin").show()

# %%
## Converting String variable : result margin into integer type
from pyspark.sql.types import DoubleType, IntegerType, StringType

ipl_dataframe = ipl_dataframe.withColumn('result_margin', col('result_margin').cast(IntegerType()))
# cases = cases.withColumn('city', F.col('city').cast(StringType()))
ipl_dataframe
# Out:
# Out[65]: DataFrame[id: int, city: string, date: date, player_of_match: string, venue: string, neutral_venue: int, team1: string, team2: string, toss_winner: string, toss_decision: string, Winning_team_name: string, result: string, result_margin: int, eliminator: string, method: string, umpire1: string, umpire2: string]

# %%
ipl_dataframe.printSchema()
# Out:
# root
#  |-- id: integer (nullable = true)
#  |-- city: string (nullable = true)
#  |-- date: date (nullable = true)
#  |-- player_of_match: string (nullable = true)
#  |-- venue: string (nullable = true)
#  |-- neutral_venue: integer (nullable = true)
#  |-- team1: string (nullable = true)
#  |-- team2: string (nullable = true)
#  |-- toss_winner: string (nullable = true)
#  |-- toss_decision: string (nullable = true)
#  |-- Winning_team_name: string (nullable = true)
#  |-- result: string (nullable = true)
#  |-- result_margin: integer (nullable = true)
#  |-- eliminator: string (nullable = true)
#  |-- method: string (nullable = true)
#  |-- umpire1: string (nullable = true)
#  |-- umpire2: string (nullable = true)

# %%
ipl_dataframe.select("result").distinct().show()
# Out:
# +-------+
# | result|
# +-------+
# |wickets|
# |     NA|
# |   runs|
# |    tie|
# +-------+

# %%
mi_home_wins = ipl_dataframe.filter((ipl_dataframe.Winning_team_name=="Mumbai Indians") &             (ipl_dataframe.city=='Mumbai')).select("id").distinct().count()

print("Number of Matches won by MI in their home ground : ",mi_home_wins)
# Out:
# Number of Matches won by MI in their home ground :  53

# %%
## Maximum and Minimum Run Margin scored by Chennai Super Kings
from pyspark.sql.functions import mean, min, max

csk_max_result_margin_runs = ipl_dataframe.filter((ipl_dataframe.Winning_team_name=="Chennai Super Kings") &             (ipl_dataframe.result=='runs')).select([max("result_margin"),min("result_margin")])

## Result shows that maxium run margin and minimum margin by CSK winning matchs
csk_max_result_margin_runs.show()
# Out:
# +------------------+------------------+
# |max(result_margin)|min(result_margin)|
# +------------------+------------------+
# |                97|                 1|
# +------------------+------------------+

# %%
#Sorting dataframe
from pyspark.sql import functions as F

csk_max_result_margin_runs = ipl_dataframe.filter((ipl_dataframe.Winning_team_name=="Chennai Super Kings") &             (ipl_dataframe.result=='runs'))

csk_max_result_margin_runs.select("id","city","team1","team2","Winning_team_name","result_margin").sort(F.desc("result_margin")).show()
# Out:
# +-------+--------------+--------------------+--------------------+-------------------+-------------+
# |     id|          city|               team1|               team2|  Winning_team_name|result_margin|
# +-------+--------------+--------------------+--------------------+-------------------+-------------+
# | 829753|       Chennai| Chennai Super Kings|     Kings XI Punjab|Chennai Super Kings|           97|
# | 729293|     Abu Dhabi| Chennai Super Kings|    Delhi Daredevils|Chennai Super Kings|           93|
# | 392185|Port Elizabeth|Royal Challengers...| Chennai Super Kings|Chennai Super Kings|           92|
# | 548380|       Chennai|    Delhi Daredevils| Chennai Super Kings|Chennai Super Kings|           86|
# | 598020|         Delhi|    Delhi Daredevils| Chennai Super Kings|Chennai Super Kings|           86|
# |1178425|       Chennai| Chennai Super Kings|      Delhi Capitals|Chennai Super Kings|           80|
# | 392209|   East London| Chennai Super Kings|     Deccan Chargers|Chennai Super Kings|           78|
# | 598051|     Hyderabad| Sunrisers Hyderabad| Chennai Super Kings|Chennai Super Kings|           77|
# | 548311| Visakhapatnam|     Deccan Chargers| Chennai Super Kings|Chennai Super Kings|           74|
# |1136577|          Pune| Chennai Super Kings|    Rajasthan Royals|Chennai Super Kings|           64|
# | 501249|        Jaipur|    Rajasthan Royals| Chennai Super Kings|Chennai Super Kings|           63|
# | 501271|       Chennai| Chennai Super Kings|Royal Challengers...|Chennai Super Kings|           58|
# | 419113|       Kolkata|Kolkata Knight Ri...| Chennai Super Kings|Chennai Super Kings|           55|
# | 598070|         Delhi| Chennai Super Kings|      Mumbai Indians|Chennai Super Kings|           48|
# | 829711|       Chennai| Chennai Super Kings| Sunrisers Hyderabad|Chennai Super Kings|           45|
# | 392202|     Centurion| Chennai Super Kings|    Rajasthan Royals|Chennai Super Kings|           38|
# | 419163|        Mumbai| Chennai Super Kings|     Deccan Chargers|Chennai Super Kings|           38|
# | 548379|     Bangalore| Chennai Super Kings|      Mumbai Indians|Chennai Super Kings|           38|
# | 598038|          Pune|       Pune Warriors| Chennai Super Kings|Chennai Super Kings|           37|
# | 733971|        Ranchi| Chennai Super Kings|Kolkata Knight Ri...|Chennai Super Kings|           34|
# +-------+--------------+--------------------+--------------------+-------------------+-------------+
# only showing top 20 rows

# %%
## Lets use groupby function to find out team wise most awarded player of the match

## we use groupBy function and passing Winning team and Player of the match columns , so that it will give us the team , player wise number of awards 

## agg function is to consolidate the group by results 
ipl_dataframe.groupBy(["Winning_team_name","player_of_match"]).agg(F.count("id").alias("Number_of_POM")).show()
# Out:
# +--------------------+---------------+-------------+
# |   Winning_team_name|player_of_match|Number_of_POM|
# +--------------------+---------------+-------------+
# | Sunrisers Hyderabad|       A Mishra|            4|
# |    Delhi Daredevils|         Z Khan|            1|
# |Kolkata Knight Ri...|       CH Gayle|            1|
# |    Delhi Daredevils|      CH Morris|            1|
# |     Deccan Chargers|       A Mishra|            2|
# | Chennai Super Kings|         P Negi|            1|
# |      Mumbai Indians|     MEK Hussey|            2|
# |      Mumbai Indians|        A Nehra|            1|
# |     Deccan Chargers|       HH Gibbs|            1|
# |    Rajasthan Royals|        KK Nair|            1|
# |    Rajasthan Royals|       DJ Hooda|            1|
# |      Delhi Capitals|       A Mishra|            1|
# |Royal Challengers...|   KP Pietersen|            2|
# |    Delhi Daredevils|     MA Agarwal|            1|
# |    Delhi Daredevils|       A Mishra|            4|
# |      Mumbai Indians|      KV Sharma|            1|
# |      Mumbai Indians| MJ McClenaghan|            2|
# | Chennai Super Kings|      AT Rayudu|            3|
# |     Kings XI Punjab|       SE Marsh|            9|
# | Sunrisers Hyderabad|        A Zampa|            1|
# +--------------------+---------------+-------------+
# only showing top 20 rows

# %%
# ## For Mathematical operations , Join , lets use a new dataset which is ball by ball record 
# ### Reading file and converting into Dataframe
# # File location and type
# dbutils.fs.ls("/FileStore/tables/") 
# # let's consider IPL matches dataset
# file_location = "/FileStore/tables/IPL_Ball_by_Ball_2008_2020.csv"
# file_type = "csv"
# ##read csv files using spark.read.csv function 
# ipl_ball_df = spark.read.csv(file_location, inferSchema = True, header = True) 
# ipl_ball_df.show(5)

ipl_ball_df = spark.read.format("csv").option("header", "true").load("dbfs:/FileStore/shared_uploads/darshan.ingle@thadomal.org/IPL_Ball_by_Ball_2008_2020-3.csv", inferSchema = True, header = True) 
ipl_ball_df.show(5)
# Out:
# +------+------+----+----+-----------+-----------+---------+------------+----------+----------+------------+---------+--------------+----------------+-------+-----------+--------------------+--------------------+
# |    id|inning|over|ball|    batsman|non_striker|   bowler|batsman_runs|extra_runs|total_runs|non_boundary|is_wicket|dismissal_kind|player_dismissed|fielder|extras_type|        batting_team|        bowling_team|
# +------+------+----+----+-----------+-----------+---------+------------+----------+----------+------------+---------+--------------+----------------+-------+-----------+--------------------+--------------------+
# |335982|     1|   6|   5| RT Ponting|BB McCullum|AA Noffke|           1|         0|         1|           0|        0|            NA|              NA|     NA|         NA|Kolkata Knight Ri...|Royal Challengers...|
# |335982|     1|   6|   6|BB McCullum| RT Ponting|AA Noffke|           1|         0|         1|           0|        0|            NA|              NA|     NA|         NA|Kolkata Knight Ri...|Royal Challengers...|
# |335982|     1|   7|   1|BB McCullum| RT Ponting|   Z Khan|           0|         0|         0|           0|        0|            NA|              NA|     NA|         NA|Kolkata Knight Ri...|Royal Challengers...|
# |335982|     1|   7|   2|BB McCullum| RT Ponting|   Z Khan|           1|         0|         1|           0|        0|            NA|              NA|     NA|         NA|Kolkata Knight Ri...|Royal Challengers...|
# |335982|     1|   7|   3| RT Ponting|BB McCullum|   Z Khan|           1|         0|         1|           0|        0|            NA|              NA|     NA|         NA|Kolkata Knight Ri...|Royal Challengers...|
# +------+------+----+----+-----------+-----------+---------+------------+----------+----------+------------+---------+--------------+----------------+-------+-----------+--------------------+--------------------+
# only showing top 5 rows

# %%
## Joining Match dataset and balls dataset 

# join function is used for merging two datasets
# we need to pass on condition for the matching columns ie ipl_dataframe.id==ipl_ball_df.id
# how parameter defines the type of join
# even after we merged the datasets , we can access the columns with the orgin dataframe name

combined_dataset = ipl_dataframe.join(ipl_ball_df,ipl_dataframe.id==ipl_ball_df.id,how='inner')

combined_dataset.select(ipl_dataframe.id,"team1","team2","city","player_of_match","inning","over","ball","batsman","bowler","total_runs","is_wicket","batting_team","bowling_team")
# Out:
# Out[76]: DataFrame[id: int, team1: string, team2: string, city: string, player_of_match: string, inning: int, over: int, ball: int, batsman: string, bowler: string, total_runs: int, is_wicket: int, batting_team: string, bowling_team: string]

# %%
### Let's find the highest run scored batsman and highest wickets taken bowler in Chennai Ground match 

## Combine the dataset
combined_dataset = ipl_dataframe.join(ipl_ball_df,ipl_dataframe.id==ipl_ball_df.id,how='inner')

## select the required dataset
adsDf=combined_dataset.select(ipl_dataframe.id,"team1","team2","city","player_of_match","inning","over","ball","batsman","bowler","total_runs","is_wicket","batting_team","bowling_team")

adsDf.filter(adsDf.city=="Chennai").groupBy("id","batsman").agg(F.sum("total_runs").alias("Batsman_runs")).sort(F.desc("Batsman_runs")).show()
adsDf.filter(adsDf.city=="Chennai").groupBy("id","bowler").agg(F.sum("is_wicket").alias("bowler_wickets")).sort(F.desc("bowler_wickets")).show()
# Out:
# +-------+-----------+------------+
# |     id|    batsman|Batsman_runs|
# +-------+-----------+------------+
# | 419137|    M Vijay|         128|
# | 548380|    M Vijay|         119|
# | 598034|   MS Bisla|         108|
# | 829711|BB McCullum|         107|
# | 598026|  SR Watson|         106|
# | 598041|   SK Raina|         102|
# | 419137|    NV Ojha|          99|
# |1178416|  SR Watson|          98|
# | 501271|    M Vijay|          97|
# | 501270|   CH Gayle|          96|
# | 598034| MEK Hussey|          95|
# | 336033|   GC Smith|          93|
# | 548381|   MS Bisla|          93|
# | 598026| MEK Hussey|          91|
# | 335989|  ML Hayden|          89|
# |1136565| AD Russell|          89|
# | 829797|BB McCullum|          88|
# | 501211| MEK Hussey|          86|
# | 419153|   SK Raina|          85|
# |1178416|  MK Pandey|          84|
# +-------+-----------+------------+
# only showing top 20 rows
#
# +-------+---------------+--------------+
# |     id|         bowler|bowler_wickets|
# +-------+---------------+--------------+
# | 336013|       L Balaji|             5|
# | 548380|       R Ashwin|             5|
# | 336029|      JA Morkel|             4|
# | 548318|   DE Bollinger|             4|
# | 501236|        PP Ojha|             4|
# | 548306|     SL Malinga|             4|
# | 501226|      JA Morkel|             4|
# | 598026|    JP Faulkner|             4|
# | 829779|       MA Starc|             4|
# | 829797|      RA Jadeja|             4|
# | 829707|        A Nehra|             4|
# |1178425|    Imran Tahir|             4|
# |1178419|     SL Malinga|             4|
# |1175356|Harbhajan Singh|             4|
# | 336029|       DW Steyn|             3|
# | 419121|      JA Morkel|             3|
# | 419153|       R Ashwin|             3|
# | 501226|      JE Taylor|             3|
# | 419110|     WPUJC Vaas|             3|
# | 548318| M Muralitharan|             3|
# +-------+---------------+--------------+
# only showing top 20 rows

# %%
## Using SQL to Query the Dataframes 

## createOrReplaceTempView function used to register the dataframe as temperory view / t

ipl_dataframe.createOrReplaceTempView("ipl_data")

spark.sql("SELECT city , Winning_team_name , count(id) as wins from ipl_data group by city , Winning_team_name Order by city , wins ").show()
# Out:
# +---------+--------------------+----+
# |     city|   Winning_team_name|wins|
# +---------+--------------------+----+
# |Abu Dhabi|      Delhi Capitals|   2|
# |Abu Dhabi|     Kings XI Punjab|   2|
# |Abu Dhabi| Sunrisers Hyderabad|   2|
# |Abu Dhabi|Royal Challengers...|   2|
# |Abu Dhabi| Chennai Super Kings|   3|
# |Abu Dhabi|Kolkata Knight Ri...|   6|
# |Abu Dhabi|    Rajasthan Royals|   6|
# |Abu Dhabi|      Mumbai Indians|   6|
# |Ahmedabad|Royal Challengers...|   1|
# |Ahmedabad|    Delhi Daredevils|   1|
# |Ahmedabad| Sunrisers Hyderabad|   1|
# |Ahmedabad|      Mumbai Indians|   1|
# |Ahmedabad|     Kings XI Punjab|   1|
# |Ahmedabad|    Rajasthan Royals|   7|
# |Bangalore|       Gujarat Lions|   1|
# |Bangalore|     Deccan Chargers|   1|
# |Bangalore|Rising Pune Super...|   1|
# |Bangalore|                  NA|   2|
# |Bangalore| Sunrisers Hyderabad|   2|
# |Bangalore|    Delhi Daredevils|   3|
# +---------+--------------------+----+
# only showing top 20 rows

# %% [markdown]
# ## Window Functions

# %%
# lets define a demonstration DataFrame to work on window functions
import pandas as pd 

df_data = {'partition': ['a','a', 'a', 'a', 'b', 'b', 'b', 'c', 'c',],
           'col_1': [1,1,1,1,2,2,2,3,3,], 
           'aggregation': [1,2,3,4,5,6,7,8,9,],
           'ranking': [4,3,2,1,1,1,3,1,5,],
           'lagging': [9,8,7,6,5,4,3,2,1,],
           'cumulative': [1,2,4,6,1,1,1,20,30,],
          }
df_pandas = pd.DataFrame.from_dict(df_data)
# create spark dataframe
df = spark.createDataFrame(df_pandas)

df.show()
# Out:
# +---------+-----+-----------+-------+-------+----------+
# |partition|col_1|aggregation|ranking|lagging|cumulative|
# +---------+-----+-----------+-------+-------+----------+
# |        a|    1|          1|      4|      9|         1|
# |        a|    1|          2|      3|      8|         2|
# |        a|    1|          3|      2|      7|         4|
# |        a|    1|          4|      1|      6|         6|
# |        b|    2|          5|      1|      5|         1|
# |        b|    2|          6|      1|      4|         1|
# |        b|    2|          7|      3|      3|         1|
# |        c|    3|          8|      1|      2|        20|
# |        c|    3|          9|      5|      1|        30|
# +---------+-----+-----------+-------+-------+----------+

# %%
# aggregation functions use the simplest form of window 
# which just defines grouping
from pyspark.sql import Window
from pyspark.sql import functions as F
# create partition windows on the column partition
aggregation_window = Window.partitionBy('partition')
# then we can use this window function for our aggregations on each partitions
df_aggregations = df.select(
    'partition', 'aggregation'
).withColumn(
    'aggregation_sum', F.sum('aggregation').over(aggregation_window),
).withColumn(
    'aggregation_avg', F.avg('aggregation').over(aggregation_window),
).withColumn(
    'aggregation_min', F.min('aggregation').over(aggregation_window),
).withColumn(
    'aggregation_max', F.max('aggregation').over(aggregation_window),
)
df_aggregations.show()
# note that after this operation the row order of display within the dataframe may have changed
# Out:
# +---------+-----------+---------------+---------------+---------------+---------------+
# |partition|aggregation|aggregation_sum|aggregation_avg|aggregation_min|aggregation_max|
# +---------+-----------+---------------+---------------+---------------+---------------+
# |        a|          1|             10|            2.5|              1|              4|
# |        a|          2|             10|            2.5|              1|              4|
# |        a|          3|             10|            2.5|              1|              4|
# |        a|          4|             10|            2.5|              1|              4|
# |        b|          5|             18|            6.0|              5|              7|
# |        b|          6|             18|            6.0|              5|              7|
# |        b|          7|             18|            6.0|              5|              7|
# |        c|          8|             17|            8.5|              8|              9|
# |        c|          9|             17|            8.5|              8|              9|
# +---------+-----------+---------------+---------------+---------------+---------------+

# %%
# lets define a ranking window
ranking_window = Window.partitionBy('partition').orderBy('ranking')

df_ranks = df.select(
  'partition', 'ranking'
).withColumn(
  # note that fn.row_number() does not take any arguments
  'ranking_row_number', F.row_number().over(ranking_window) 
).withColumn(
  # rank will leave spaces in ranking to account for preceding rows receiving equal ranks
  'ranking_rank', F.rank().over(ranking_window)
).withColumn(
  # dense rank does not account for previous equal rankings
  'ranking_dense_rank', F.dense_rank().over(ranking_window)
).withColumn(
  # percent rank ranges between 0-1 not 0-100
  'ranking_percent_rank', F.percent_rank().over(ranking_window)
).withColumn(
  # fn.ntile takes a parameter for now many 'buckets' to divide rows into when ranking
  'ranking_ntile_rank', F.ntile(2).over(ranking_window)
)

df_ranks.show()
# Out:
# +---------+-------+------------------+------------+------------------+--------------------+------------------+
# |partition|ranking|ranking_row_number|ranking_rank|ranking_dense_rank|ranking_percent_rank|ranking_ntile_rank|
# +---------+-------+------------------+------------+------------------+--------------------+------------------+
# |        a|      1|                 1|           1|                 1|                 0.0|                 1|
# |        a|      2|                 2|           2|                 2|  0.3333333333333333|                 1|
# |        a|      3|                 3|           3|                 3|  0.6666666666666666|                 2|
# |        a|      4|                 4|           4|                 4|                 1.0|                 2|
# |        b|      1|                 1|           1|                 1|                 0.0|                 1|
# |        b|      1|                 2|           1|                 1|                 0.0|                 1|
# |        b|      3|                 3|           3|                 2|                 1.0|                 2|
# |        c|      1|                 1|           1|                 1|                 0.0|                 1|
# |        c|      5|                 2|           2|                 2|                 1.0|                 2|
# +---------+-------+------------------+------------+------------------+--------------------+------------------+

# %%
lag_window = Window.partitionBy('partition').orderBy('lagging')

df_lagged = df.select(
  'partition', 'lagging'
).withColumn(
  # note that lag requires both column and lag amount to be specified
  # It is possible to lag a column which was not the orderBy column
  'lagging_lag_1', F.lag('lagging', 1).over(lag_window)
).withColumn(
  'lagging_lag_2', F.lag('lagging', 2).over(lag_window)
).withColumn(
  'lagging_lead_1', F.lead('lagging', 1).over(lag_window)
).withColumn(
  # note how 'lagging_lag_1' == 'lagging_lead_minus_1'
  'lagging_lead_minus_1', F.lead('lagging', -1).over(lag_window)
).withColumn(
  # we can also perform calculations between lagged and unlagged columns of course
  'difference_between', F.col('lagging') - F.lag('lagging', 1).over(lag_window)
)

df_lagged.show()
# Out:
# +---------+-------+-------------+-------------+--------------+--------------------+------------------+
# |partition|lagging|lagging_lag_1|lagging_lag_2|lagging_lead_1|lagging_lead_minus_1|difference_between|
# +---------+-------+-------------+-------------+--------------+--------------------+------------------+
# |        a|      6|         null|         null|             7|                null|              null|
# |        a|      7|            6|         null|             8|                   6|                 1|
# |        a|      8|            7|            6|             9|                   7|                 1|
# |        a|      9|            8|            7|          null|                   8|                 1|
# |        b|      3|         null|         null|             4|                null|              null|
# |        b|      4|            3|         null|             5|                   3|                 1|
# |        b|      5|            4|            3|          null|                   4|                 1|
# |        c|      1|         null|         null|             2|                null|              null|
# |        c|      2|            1|         null|          null|                   1|                 1|
# +---------+-------+-------------+-------------+--------------+--------------------+------------------+

# %%
pandas_ipl = ipl_dataframe.to_pandas_on_spark()
pandas_ipl.head(2)
# Out:
# /databricks/spark/python/pyspark/sql/dataframe.py:3607: FutureWarning: DataFrame.to_pandas_on_spark is deprecated. Use DataFrame.pandas_api instead.
#   warnings.warn(
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>city</th>
#       <th>date</th>
#       <th>player_of_match</th>
#       <th>venue</th>
#       <th>neutral_venue</th>
#       <th>team1</th>
#       <th>team2</th>
#       <th>toss_winner</th>
#       <th>toss_decision</th>
#       <th>Winning_team_name</th>
#       <th>result</th>
#       <th>result_margin</th>
#       <th>eliminator</th>
#       <th>method</th>
#       <th>umpire1</th>
#       <th>umpire2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>335982</td>
#       <td>Bangalore</td>
#       <td>2008-04-18</td>
#       <td>BB McCullum</td>
#       <td>M Chinnaswamy Stadium</td>
#       <td>0</td>
#       <td>Royal Challengers Bangalore</td>
#       <td>Kolkata Knight Riders</td>
#       <td>Royal Challengers Bangalore</td>
#       <td>field</td>
#       <td>Kolkata Knight Riders</td>
#       <td>runs</td>
#       <td>140</td>
#       <td>N</td>
#       <td>NA</td>
#       <td>Asad Rauf</td>
#       <td>RE Koertzen</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>335983</td>
#       <td>Chandigarh</td>
#       <td>2008-04-19</td>
#       <td>MEK Hussey</td>
#       <td>Punjab Cricket Association Stadium, Mohali</td>
#       <td>0</td>
#       <td>Kings XI Punjab</td>
#       <td>Chennai Super Kings</td>
#       <td>Chennai Super Kings</td>
#       <td>bat</td>
#       <td>Chennai Super Kings</td>
#       <td>runs</td>
#       <td>33</td>
#       <td>N</td>
#       <td>NA</td>
#       <td>MR Benson</td>
#       <td>SL Shastri</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Happy Learning
